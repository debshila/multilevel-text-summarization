# %% [markdown]
# # Preprocessing privacy and opt-out policies

# %%
# general imports
import warnings
import nltk
import pandas as pd
import numpy as np
import scipy as sp
from time import time, sleep
import json
import requests
import random
import os
import matplotlib.pyplot as plt
import re
from xml.etree import cElementTree as ET
from sklearn.externals import joblib
# Clean and lemmatize text
from nltk.corpus import stopwords
from gensim.utils import smart_open, simple_preprocess
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.tokenize import sent_tokenize, word_tokenize
import html5lib
import re
from bs4 import BeautifulSoup
import requests
from pprint import pprint
from pickle import dump,load
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
from pprint import pprint

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt

# Enable logging for gensim - optional
import logging
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

warnings.filterwarnings("ignore", category=DeprecationWarning)

random.seed(0)
# %matplotlib inline

# %%
# Directory paths
pp_dir = '/Users/dbm/Downloads/OPP-115/sanitized_policies/'
oo_dir = '/Users/dbm/Downloads/OptOutChoice-2017_v1.0/SanitizedPrivacyPolicies/'
pp_xml = '/Users/dbm/Downloads/corpus/'

# %%
# Read in all story files
def ls_fullpath(directory):
    return [os.path.join(directory, f) for f in os.listdir(directory)]

# %%
def extract_co_name(file, pat='\d+_|\.com|\.edu|\.html|\.xml|www_|_co'):
    co_name = re.sub(pattern=pat, repl='', string=os.path.basename(file))
    return co_name

# %%
# Read in files
pp_files = ls_fullpath(directory=pp_dir)
oo_files = ls_fullpath(directory=oo_dir)
oo_files = [i for i in oo_files if '.DS_Store' not in i]
pp_xml_files = ls_fullpath(directory=pp_xml)
print(pp_xml_files)
# Out:
# ['/Users/dbm/Downloads/corpus/www_google_co_nz.xml', '/Users/dbm/Downloads/corpus/ibnlive_in.xml', '/Users/dbm/Downloads/corpus/www_gocomics.xml', '/Users/dbm/Downloads/corpus/www_petsmart.xml', '/Users/dbm/Downloads/corpus/www_duolingo.xml', '/Users/dbm/Downloads/corpus/www_usda_gov.xml', '/Users/dbm/Downloads/corpus/www_fcbarcelona.xml', '/Users/dbm/Downloads/corpus/static_zara_net.xml', '/Users/dbm/Downloads/corpus/www_infowars.xml', '/Users/dbm/Downloads/corpus/www_change_org.xml', '/Users/dbm/Downloads/corpus/www_uefa.xml', '/Users/dbm/Downloads/corpus/www_washingtontimes.xml', '/Users/dbm/Downloads/corpus/english_alarabiya_net.xml', '/Users/dbm/Downloads/corpus/www_esquire.xml', '/Users/dbm/Downloads/corpus/www_netdoctor_co_uk.xml', '/Users/dbm/Downloads/corpus/gamespress.xml', '/Users/dbm/Downloads/corpus/www_flashscore.xml', '/Users/dbm/Downloads/corpus/www_abovetopsecret.xml', '/Users/dbm/Downloads/corpus/www_breitbart.xml', '/Users/dbm/Downloads/corpus/www_soccervista.xml', '/Users/dbm/Downloads/corpus/www_chillingeffects_org.xml', '/Users/dbm/Downloads/corpus/www_accorhotels.xml', '/Users/dbm/Downloads/corpus/www_livingsocial.xml', '/Users/dbm/Downloads/corpus/www_cvs.xml', '/Users/dbm/Downloads/corpus/www_scout.xml', '/Users/dbm/Downloads/corpus/www_fotolia.xml', '/Users/dbm/Downloads/corpus/www_opentable.xml', '/Users/dbm/Downloads/corpus/www_king.xml', '/Users/dbm/Downloads/corpus/www_petmd.xml', '/Users/dbm/Downloads/corpus/www_about.xml', '/Users/dbm/Downloads/corpus/www_theverge.xml', '/Users/dbm/Downloads/corpus/www_microsoft.xml', '/Users/dbm/Downloads/corpus/www_drugstore.xml', '/Users/dbm/Downloads/corpus/www_saksfifthavenue.xml', '/Users/dbm/Downloads/corpus/www_oracle.xml', '/Users/dbm/Downloads/corpus/www_cars.xml', '/Users/dbm/Downloads/corpus/www_care.xml', '/Users/dbm/Downloads/corpus/www_aeropostale.xml', '/Users/dbm/Downloads/corpus/www_mozilla_org.xml', '/Users/dbm/Downloads/corpus/www_mayoclinic.xml', '/Users/dbm/Downloads/corpus/companieshouse_gov_uk.xml', '/Users/dbm/Downloads/corpus/www_chron.xml', '/Users/dbm/Downloads/corpus/www_dynamicdrive.xml', '/Users/dbm/Downloads/corpus/www_egotastic.xml', '/Users/dbm/Downloads/corpus/www_cambridge_org.xml', '/Users/dbm/Downloads/corpus/www_cms_gov.xml', '/Users/dbm/Downloads/corpus/curezone_org.xml', '/Users/dbm/Downloads/corpus/www_avg.xml', '/Users/dbm/Downloads/corpus/www_cbc_ca.xml', '/Users/dbm/Downloads/corpus/earthclinic.xml', '/Users/dbm/Downloads/corpus/www_weather.xml', '/Users/dbm/Downloads/corpus/www_pearsoned.xml', '/Users/dbm/Downloads/corpus/www_utm_utoronto_ca.xml', '/Users/dbm/Downloads/corpus/www_couchsurfing_org.xml', '/Users/dbm/Downloads/corpus/www_wikia.xml', '/Users/dbm/Downloads/corpus/www_travelzoo.xml', '/Users/dbm/Downloads/corpus/www_linkedin.xml', '/Users/dbm/Downloads/corpus/www_mtgox.xml', '/Users/dbm/Downloads/corpus/biblehub.xml', '/Users/dbm/Downloads/corpus/www_bounty.xml', '/Users/dbm/Downloads/corpus/www_staples.xml', '/Users/dbm/Downloads/corpus/www_edmunds.xml', '/Users/dbm/Downloads/corpus/www_nlm_nih_gov.xml', '/Users/dbm/Downloads/corpus/pro_bitcoincharts.xml', '/Users/dbm/Downloads/corpus/bitpay.xml', '/Users/dbm/Downloads/corpus/www_freelancer.xml', '/Users/dbm/Downloads/corpus/www_restaurant.xml', '/Users/dbm/Downloads/corpus/www_ford.xml', '/Users/dbm/Downloads/corpus/www2_epa_gov.xml', '/Users/dbm/Downloads/corpus/www_gm.xml', '/Users/dbm/Downloads/corpus/www_fark.xml', '/Users/dbm/Downloads/corpus/www_jcpenney.xml', '/Users/dbm/Downloads/corpus/www_futureplc.xml', '/Users/dbm/Downloads/corpus/www_ypg.xml', '/Users/dbm/Downloads/corpus/www_officedepot.xml', '/Users/dbm/Downloads/corpus/aboutus_lego.xml', '/Users/dbm/Downloads/corpus/www_verizon.xml', '/Users/dbm/Downloads/corpus/www_forever21.xml', '/Users/dbm/Downloads/corpus/www_nhl.xml', '/Users/dbm/Downloads/corpus/www_samsung.xml', '/Users/dbm/Downloads/corpus/www_sprint.xml', '/Users/dbm/Downloads/corpus/om_yr_no.xml', '/Users/dbm/Downloads/corpus/w ...

# %%
# Extract company names from filenames
co_names_pp = [extract_co_name(file=file) for file in pp_files]
co_names_oo = [extract_co_name(file=file) for file in oo_files]
co_names_ppxml = [extract_co_name(file=file) for file in pp_xml_files]
co_names = co_names_pp + co_names_oo
co_names_ppxml
# Out:
# ['google_nz',
#  'ibnlive_in',
#  'gocomics',
#  'petsmart',
#  'duolingo',
#  'usda_gov',
#  'fcbarcelona',
#  'static_zara_net',
#  'infowars',
#  'change_org',
#  'uefa',
#  'washingtontimes',
#  'english_alarabiya_net',
#  'esquire',
#  'netdoctor_uk',
#  'gamespress',
#  'flashscore',
#  'abovetopsecret',
#  'breitbart',
#  'soccervista',
#  'chillingeffects_org',
#  'accorhotels',
#  'livingsocial',
#  'cvs',
#  'scout',
#  'fotolia',
#  'opentable',
#  'king',
#  'petmd',
#  'about',
#  'theverge',
#  'microsoft',
#  'drugstore',
#  'saksfifthavenue',
#  'oracle',
#  'cars',
#  'care',
#  'aeropostale',
#  'mozilla_org',
#  'mayoclinic',
#  'companieshouse_gov_uk',
#  'chron',
#  'dynamicdrive',
#  'egotastic',
#  'cambridge_org',
#  'cms_gov',
#  'curezone_org',
#  'avg',
#  'cbc_ca',
#  'earthclinic',
#  'weather',
#  'pearsoned',
#  'utm_utoronto_ca',
#  'couchsurfing_org',
#  'wikia',
#  'travelzoo',
#  'linkedin',
#  'mtgox',
#  'biblehub',
#  'bounty',
#  'staples',
#  'edmunds',
#  'nlm_nih_gov',
#  'pro_bitcoincharts',
#  'bitpay',
#  'freelancer',
#  'restaurant',
#  'ford',
#  'wwwepa_gov',
#  'gm',
#  'fark',
#  'jcpenney',
#  'futureplc',
#  'ypg',
#  'officedepot',
#  'aboutus_lego',
#  'verizon',
#  'forever21',
#  'nhl',
#  'samsung',
#  'sprint',
#  'om_yr_no',
#  'alternet_org',
#  'sitesell',
#  'cafemom',
#  'wowhead',
#  'php_net',
#  'peoplesmart',
#  'turkishairlines',
#  'hkjc',
#  'mnn',
#  'amazon_jp',
#  'filmaffinity',
#  'mashable',
#  'oprah',
#  'spinmedia',
#  'prnewswire_mediaroom',
#  'sheknows',
#  'allrecipes',
#  'aafp_org',
#  'flipkart',
#  'cpsc_gov',
#  'stevepavlina',
#  'usa_canon',
#  'mtv',
#  'bedbathandbeyond',
#  'ubi',
#  'tripadvisor_in',
#  'daveramsey',
#  'mlbtraderumors',
#  'inside_monster',
#  'dropbox',
#  'teamliquid_net',
#  'irishtimes',
#  'funtrivia',
#  'media_townhall',
#  'pillsbury',
#  'newegg',
#  'mediafire',
#  'ets_org',
#  'digg',
#  '9gag',
#  'bbc_uk',
#  'vrbo',
#  'help_sky',
#  'rottentomatoes',
#  'bitstamp_net',
#  'asos',
#  'acs_org',
#  'khanacademy_org',
#  'mailchimp',
#  'bbb_org',
#  'datehookup',
#  'researchgate_net',
#  'thekitchn',
#  'spine-health',
#  'patient_uk',
#  'group_bmj',
#  'newsm_au',
#  'biomedcentral',
#  'kidshealth_org',
#  'alaskaair',
#  'thesaurus',
#  'espncricinfo',
#  'worg',
#  'sitepoint',
#  'hulu',
#  'service_prweb',
#  'target',
#  'anthropologie',
#  'online_wsj',
#  'fidelity',
#  'irctc_in',
#  'va_gov',
#  'quikr',
#  'colorado_edu',
#  'directv',
#  'ivillage',
#  'gamestop',
#  'usgs_gov',
#  'easybib',
#  'tos_ea',
#  'wikimediafoundation_org',
#  'bom_gov_au',
#  'nickjr',
#  'corporate_walmart',
#  'flalottery',
#  'ieee_org',
#  'blackfriday',
#  'sulekha',
#  'naturallycurly',
#  'consumerreports_org',
#  'ufc',
#  'nick',
#  'freerepublic',
#  'barnesandnoble',
#  'liverpoolfc',
#  'conversion-metric_org',
#  'craveonline',
#  'elance',
#  'ea',
#  'classified_bdnews24',
#  'bestbuy',
#  'manta',
#  'moneycontrol',
#  'signup_netflix',
#  '4shared',
#  'pegym',
#  'boxingscene',
#  'manutd',
#  'gmx',
#  'webmd',
#  'cnbc',
#  'uspto_gov',
#  'cartoonnetwork',
#  'geocaching',
#  'aircanada',
#  'speedtest_net',
#  'med_nyu_edu',
#  'jstor_org',
#  'eurogamer_net',
#  'avforums',
#  'pinkbike',
#  'fifa',
#  'aarp_org',
#  'profootballtalk_nbcsports',
#  'rodaleinc',
#  'eatingwell',
#  'help_overstock',
#  'interpals_net',
#  'styleforum_net',
#  '123rf',
#  'complex',
#  'commbankm_au',
#  'superpages',
#  'cosmopolitan',
#  'sutterhealth_org',
#  'menshealth_uk',
#  'jobsearch_naukri',
#  'ucla_edu',
#  'military',
#  'cracked',
#  'my_clevelandclinic_org',
#  'bls_gov',
#  'urbandictionary',
#  'legal_kinja',
#  'cambridgeindia_org',
#  'ultimate-guitar',
#  'heavy',
#  'zazzle',
#  'cryptsy',
#  'gsb_stanford_edu',
#  'toysrus',
#  'valueclickmedia',
#  'vimeo',
#  'adorama',
#  'pokemon',
#  'shutterstock',
#  'udacity',
#  'nextag',
#  'monsterindia',
#  'copyscape',
#  'shop_nordstrom',
#  'dell',
#  'jal_jp',
#  'jagex',
#  'nytimes',
#  'corporate_discovery',
#  'webcrawler',
#  'virgin-atlantic',
#  'shop_lego',
#  'potterybarn',
#  'washingtonpost',
#  'aeroflot_ru',
#  'lonelyplanet',
#  'lyricsfreak',
#  'radioshack',
#  'privacy_tribune',
#  'zappos',
#  'who_int',
#  'edition_cnn',
#  'census_gov',
#  'tradedoubler',
#  'footytube',
#  'ucdavis_edu',
#  'meetup',
#  'newsvine',
#  'zip-codes',
#  'nih_gov',
#  'studentdoctor_net',
#  'skype',
#  'expedia_ca',
#  'un_org',
#  'coolmath',
#  'tomshardware',
#  'company_findlaw',
#  'facebook',
#  'amazon_ca',
#  'businessweek',
#  '6pm',
#  'nvidia',
#  'coolmath-games',
#  'en_wikipedia_org',
#  'mf_custhelp',
#  'last_fm',
#  'dynamic_focalprice',
#  'independent_uk',
#  'merriam-webster',
#  'ap_org',
#  'usa_autodesk',
#  'forexfactory',
#  'indiatimes',
#  'fandango',
#  'bnet',
#  'bet-at-home',
#  'about_usps',
#  'frys',
#  'nationalgeographic',
#  'oxforddictionaries',
#  'mapsofindia',
#  'wedding_theknot',
#  'dw_de',
#  'tonyrobbins',
#  'ticketmaster',
#  'livescore',
#  'americanexpress',
#  'auspostm_au',
#  'snapfish',
#  'biography',
#  '000webhost',
#  'sharecare',
#  'zillow',
#  'usbank',
#  'irs_gov',
#  'nypost',
#  'webopedia',
#  'automattic',
#  'arsenal',
#  'info_doccheck',
#  'eventbrite',
#  'slate',
#  'wisc_edu',
#  'lds_org',
#  'shaadi',
#  'apple',
#  'cdc_gov',
#  'ca_gov',
#  'vitals',
#  'noaa_gov',
#  'nelsonmandela_org',
#  'delta',
#  'healthy_kaiserpermanente_org',
#  'comcast',
#  'mlb_mlb',
#  'hotwire',
#  'honda',
#  'thestar',
#  'qantasm_au',
#  'dallasnews',
#  'gearslutz',
#  'shop_mercola',
#  'oneindia_in',
#  'pbskids_org',
#  'thefreedictionary',
#  'berkeley_edu',
#  'weather_gov',
#  'privacy_microsoft',
#  'nbcuni',
#  'kraftrecipes',
#  'digitalspy_uk',
#  'cms_paypal',
#  'metacafe',
#  'ucsd_edu',
#  'pages_ebay_in',
#  'fool',
#  'examiner',
#  'digitaltrends',
#  'as_wiley',
#  'wiki_xbmc_org',
#  'timeout',
#  'salemwebnetwork',
#  'fatwallet',
#  'mediaplex',
#  'bodybuilding',
#  'variety',
#  'bulbapedia_bulbagarden_net',
#  'kmart',
#  'policies_usc_edu',
#  'phonearena',
#  'ubi',
#  'dx',
#  'myhomeremedies',
#  'na_square-enix',
#  'help_ladbrokes',
#  'statcounter',
#  'horoscope',
#  'en_bitcoin_it',
#  'm_ciao_de',
#  'lotterypost',
#  'goodreads',
#  'shopathome',
#  'yelp',
#  'cheaptickets',
#  'about_ask',
#  'foursquare',
#  'ebaumsworld',
#  'ratemyprofessors',
#  'gameinformer',
#  'booking',
#  'economistgroup',
#  'acidcow',
#  'rockstargames',
#  'xmarks',
#  'unwomen_org',
#  'care2',
#  'cheatcc',
#  'help_kijiji_net',
#  'sporcle',
#  'meredith',
#  'privacy_aol',
#  'hasbro',
#  'modcloth',
#  'ubergizmo',
#  'salon',
#  'drweil',
#  'hyatt',
#  'rt',
#  'amexpub',
#  'security_berkeley_edu',
#  'msn_foxsports',
#  'udemy',
#  'acbj',
#  'hostelbookers',
#  'in_match',
#  'usa_gov',
#  'homedepot',
#  'archive_org',
#  'justjared',
#  'online_citibank',
#  'codecademy',
#  'ehow',
#  'nationalreview',
#  'consumerist',
#  'y8',
#  'airliners_net',
#  'popularmechanics',
#  'southernsavers',
#  'futureshop_ca',
#  'kongregate',
#  'ikea',
#  'wisegeek',
#  'hhonorshilton',
#  'behance_net',
#  'corporate_yp',
#  'webdeveloper',
#  'priceline',
#  'newsbusters_org',
#  'secure_avaaz_org',
#  'jcrew',
#  'theregister_uk',
#  'backcountry',
#  'spotify',
#  'rhymezone',
#  'biblegateway',
#  'info_yahoo',
#  'mckinley',
#  'nhs_uk',
#  'retailmenot',
#  'dailykos',
#  'mixedmartialarts',
#  'france24',
#  'jpost',
#  'corporate_britannica',
#  'business-standard',
#  'vg247',
#  'zenimax',
#  'healthcare_gov',
#  'wordreference',
#  'vegasinsider',
#  'weeklystandard',
#  'jobdiagnosis',
#  'theonion',
#  'jamieoliver',
#  'imdb',
#  'anticlown',
#  'fema_gov',
#  'victoriassecret',
#  'listal',
#  'newyork_bbb_org',
#  'bleacherreport',
#  'correiosm_br',
#  'agoda',
#  'cms_gov',
#  'britishairways',
#  'corporate_mediabistro',
#  'security_wmtransfer',
#  'redbull',
#  'README',
#  'indianrailways_gov_in',
#  'upenn_edu',
#  'worldcarfans',
#  'besthealthmag_ca',
#  'popsci',
#  'web_worldbank_org',
#  'zendesk',
#  'rei',
#  'salesforce',
#  'hollywoodlife',
#  'google_in',
#  'christianpost',
#  'yourtango',
#  'wwe',
#  'legal_us_ubm',
#  'dilbert',
#  'muscleandfitness',
#  'drugs',
#  'apa_org',
#  'yoox',
#  'classmates',
#  'wordpress_org',
#  'carfax',
#  'gaiaonline',
#  'blog_feedly',
#  'philly',
#  'weightwatchers',
#  'huffingtonpost',
#  'formula1',
#  'allmusic',
#  'telegraph_uk',
#  'artofmanliness',
#  'hostgator',
#  'fanfiction_net',
#  'washington_edu',
#  'niddk_nih_gov',
#  'soccermanager',
#  'trademe_nz',
#  'easyjet',
#  'ebog',
#  'hbs_edu',
#  'emirates',
#  'neopets',
#  '101greatgoals',
#  'newsnow_uk',
#  'bitcoin_org',
#  'pbs_org',
#  'onetravel',
#  'azlyrics',
#  'zedo',
#  'intermarkets_net',
#  'help_ft',
#  'newscientist',
#  'wiki_answers',
#  'google',
#  'imageshack_us',
#  'nationalreview',
#  'volvocars',
#  'thestudentroom_uk',
#  'skyscrapercity',
#  'fedex',
#  'mindmeister',
#  'htmlgoodies',
#  'activenetwork',
#  'fiverr',
#  'sephora',
#  'ajc',
#  'craigslist_org',
#  'td',
#  'store_steampowered',
#  'calottery',
#  'drrobertrey',
#  'highgearmedia',
#  'diabetes_org',
#  'collegelumbia_edu',
#  'avvo',
#  'gizmodo_in',
#  't-nation',
#  'newgrounds',
#  'ae',
#  'espn_go',
#  'usnews',
#  'lowes',
#  'cancer_org',
#  'mmajunkie',
#  'nps_gov',
#  'dol_gov',
#  'laterooms',
#  'curse',
#  'icicibank',
#  'bankrate',
#  'theglobeandmail',
#  'edx_org',
#  'megamillions',
#  'activision',
#  'myfitnesspal',
#  'istockphoto',
#  'cricbuzz',
#  'more_starfall',
#  'virtualtourist',
#  'wnd',
#  'xscores',
#  'patents_uspto_gov',
#  'rediff',
#  'netcarshow',
#  'xe',
#  'landsend',
#  'caranddriver',
#  'about_deviantart',
#  'nist_gov',
#  'expatriates',
#  'na_leagueoflegends',
#  'miniclip',
#  'roblox',
#  'help_bet365',
#  'cabelas',
#  'creativecommons_org',
#  'jw_org',
#  'accuweather',
#  'ndtv',
#  'msdn_microsoft',
#  'yardbarker',
#  'socialanxietysupport',
#  'reviewcentre',
#  'tagged',
#  'post_japanpost_jp',
#  'psychologytoday',
#  'dailymail_uk',
#  'familysearch_org',
#  'kohls',
#  'mapsofworld',
#  '192',
#  'beta_opendns',
#  'planetminecraft',
#  'wowwiki',
#  'astrom_my',
#  'chess',
#  'ripoffreport',
#  'hootsuite',
#  'ewg_org',
#  'cafepress',
#  'en_mappy',
#  'totalbeauty',
#  'zocdoc',
#  'slashdotmedia',
#  'careerbuilder',
#  'privacy_pch',
#  'slideshare_net',
#  'orbitz',
#  'btc-e',
#  'constantcontact',
#  'forums_xkcd',
#  'money_cnn',
#  'yola',
#  'ziffdavis',
#  'harvard_edu',
#  'realtor_org',
#  'wunderground',
#  'kayak_in',
#  'shabdkosh',
#  'cj',
#  'foxnews',
#  'forbes',
#  'soundcloud',
#  'christianbook',
#  'intellicast',
#  'flamingtext',
#  'support_paddypower',
#  'support_scribd',
#  'hostelworld',
#  'cathaypacific',
#  'guardianlv',
#  'shape',
#  'cooks',
#  'metoffice_gov_uk',
#  'takepart',
#  'subscription_timeinc',
#  'uscourts_gov',
#  'home_bt',
#  'rapgenius',
#  'mcafee',
#  'voanews',
#  't-mobile',
#  'greenmangaming',
#  'mirror_uk',
#  'simplyrecipes',
#  'surfline',
#  'sports-reference',
#  'foreignpolicy',
#  'redbubble',
#  'ted',
#  'utexas_edu',
#  'sciencemag_org',
#  'myfantasyleague',
#  'customerservice_macys',
#  'incisivemedia',
#  'apartmenttherapy',
#  'easycalculation',
#  'techmedianetwork',
#  'twitter',
#  'amazon_uk',
#  'bitly',
#  'rackspace',
#  'boingboing_net',
#  'corporate_mattel',
#  'theguardian',
#  'onlineconversion',
#  'ksl',
#  'covers',
#  'gametrailers',
#  'amarujala',
#  'urbanoutfitters',
#  'williams-sonoma',
#  'timeanddate',
#  'fairfaxm_au',
#  'couponsinc',
#  'girlsgogames',
#  'fixya',
#  'warnerbros',
#  'reverso_net',
#  'nba',
#  'jpl_nasa_gov',
#  'homeaway',
#  'qatarairways',
#  'howstuffworks',
#  'bellmedia_ca',
#  'legacy',
#  'medcohealth',
#  'nbcnews',
#  'joomla_org',
#  'chase',
#  'nic_in',
#  'expedia_in',
#  'boardgamegeek',
#  'marthastewart',
#  'affutd',
#  'imgur',
#  'aa',
#  'aweber',
#  'privacy_ufl_edu',
#  'socialsecurity_gov',
#  'bradsdeals',
#  'whitehouse_gov',
#  'badoo',
#  'scrippsnetworksinteractive',
#  'alibaba',
#  'wolframalpha',
#  'iberia',
#  'nbc',
#  'paypal',
#  'cbsi_secure_force',
#  'help_play',
#  'about_pinterest',
#  'becomegorgeous',
#  'online-sweepstakes',
#  'nejm_org',
#  'glispa',
#  'uploaded_net',
#  'indianrail_gov_in',
#  'amazon',
#  'sciencedaily',
#  'in_godaddy',
#  'nutrition_org',
#  'bgr',
#  'postmedia',
#  'customerservice_bloomingdales',
#  'purdue_edu',
#  'csmonitor',
#  'account_ankama',
#  'skyscanner_in',
#  'blackboard',
#  'nokia',
#  'llbean',
#  'qvc',
#  'usatoday',
#  'accounts_clickbank',
#  'help_github',
#  'cuny_edu',
#  'porsche',
#  'mmorpg',
#  'babylon',
#  'privacy_sourceinterlinkmedia',
#  'billboard',
#  'translator_babylon',
#  'archives',
#  'reuters',
#  'shopbop',
#  'dreamstime',
#  'groupon',
#  'bellasugar',
#  'southparkstudios',
#  'admin_ox_ac_uk',
#  'marketwatch',
#  'adobe',
#  'destructoid',
#  'score_org',
#  'sec_gov',
#  'lg',
#  'capitalone',
#  'kia',
#  'seattletimescompany',
#  'straightdope',
#  'livejournal',
#  'mylife',
#  'dnaindia',
#  'neimanmarcus',
#  'venere',
#  'bhphotovideo',
#  'medscape',
#  'hattrick_org',
#  'elsevier',
#  'pages_ebay',
#  'phoenix_edu',
#  'usaa',
#  'wwjustanswer',
#  'us_playstation',
#  'portal_lacaixa_es',
#  'ibtimes',
#  '24hourfitness',
#  'about_officemax',
#  'iherb',
#  'career_sdsu_edu',
#  'tinyurl',
#  'npr_org',
#  'head-fi_org',
#  'sea_blizzard',
#  'mathworks_in',
#  'hopkinsmedicine_org',
#  'googlem_au',
#  'mobile9',
#  'walgreens',
#  'dhl',
#  'yale_edu',
#  'pages_ebaym_au',
#  'info_sciencedirect',
#  'about_abc_net_au',
#  'mouthshut',
#  'saudiairlines',
#  'pages_ebay_uk',
#  'mathsisfun',
#  'yourdictionary',
#  'bettycrocker',
#  'photobucket',
#  'makeupalley',
#  'psu_edu',
#  'wwcox',
#  'usairways',
#  'pnc',
#  'xing',
#  'nfl',
#  'trulia',
#  'marriott',
#  'help-all_nike',
#  'rollingstone',
#  'ezinearticles',
#  'wine-searcher',
#  'hollywoodreporter',
#  'costco',
#  'tigerdirect',
#  'europe_cnn',
#  'nuance',
#  'bibsonomy_org',
#  'oddschecker',
#  'kbb',
#  'imperiaonline_org',
#  'discogs',
#  'disneyprivacycenter',
#  'fda_gov',
#  'addictinggames',
#  'inc',
#  'rawstory',
#  'adweek',
#  'arabic-keyboard_org',
#  'snopes',
#  'shareasale',
#  'lifehack_org',
#  'betfair',
#  'fcc_gov',
#  'brainyquote',
#  'united',
#  'wiki_openstreetmap_org',
#  'oclc_org',
#  'hrs_de',
#  'thehindu',
#  'weebly',
#  'stumbleupon',
#  'europa_eu',
#  'about_shopzilla',
#  'n4g',
#  'babycenter',
#  'stardoll',
#  'gsmarena',
#  'ana_jp',
#  'futureus',
#  'vistaprint',
#  'lumosity',
#  'sfgate',
#  'sbnation',
#  'freeonlinegames',
#  'nydailynews',
#  'loc_gov',
#  'medicinenet',
#  'williamhill_us',
#  'stubhub',
#  'indianexpress',
#  'alexa',
#  'coursera_org',
#  'collegehumor',
#  'advance_net',
#  'atpworldtour',
#  'ryanair',
#  'flightradar24',
#  'manoramaonline',
#  'intel_in',
#  'localbitcoins',
#  'dickssportinggoods',
#  'company_wizards',
#  'stackexchange',
#  'paulaschoice',
#  'petfinder',
#  'topgear',
#  'disney_in',
#  'dslreports',
#  'videogamernetwork',
#  'theatlantic',
#  'technologyreview',
#  'autosport',
#  'indeed_in',
#  'boxofficemojo',
#  'zomato',
#  'italki',
#  'pricegrabber',
#  'internetbrands',
#  '888',
#  'blockchain_info',
#  'enjin',
#  'allnurses',
#  'newsmax',
#  'net-a-porter',
#  'agb_traviangames',
#  'eonline',
#  'condenast',
#  'rxlist',
#  'basketball_realgm',
#  'surveymonkey',
#  'hairfinder',
#  'pandora',
#  'wellness',
#  'nature',
#  'dpreview',
#  'domaintools',
#  'scientificamerican',
#  'tmz',
#  'aaos_org',
#  'royalmail',
#  'reddit',
#  'cancer_gov',
#  'mathrubhumi',
#  'hi5',
#  'help_marksandspencer',
#  'topix',
#  'nyu_edu',
#  'macmillandictionary',
#  'gap',
#  'myfico',
#  'sony',
#  'corp_ign',
#  'canadapost_ca',
#  'wwwed_gov',
#  'metatalk_metafilter',
#  'klm',
#  'pixmania_uk',
#  'us_blizzard',
#  'state_gov',
#  'ancestry',
#  'mensfitness',
#  'samsclub',
#  'products_butterflylabs',
#  'southwest',
#  'fao_org',
#  'conduit',
#  'fineartamerica',
#  'whitepagescustomers',
#  'perfectworld',
#  'shutterfly',
#  'wellsfargo',
#  'travelocity',
#  'alz_org',
#  'google_ie',
#  'hm',
#  'google_uk',
#  'investopedia',
#  'videogamer',
#  'dict_leo_org',
#  'shopspaceweather',
#  'ebaycommercenetwork',
#  'apa_org',
#  'integrativenutrition',
#  'hse_gov_uk',
#  'lufthansa',
#  'fodors',
#  'entrepreneur',
#  'spanishdict',
#  'freelotto',
#  'hsn',
#  'hdfcbank',
#  'ar15',
#  'bloomberg',
#  'aenetworks',
#  'att',
#  'popsugar',
#  'vitacost',
#  'autotrader',
#  'icicibank',
#  'getresponse',
#  'airberlin',
#  'codeschool',
#  'findagrave',
#  'hindustantimes',
#  'wwwhp',
#  'bankofamerica',
#  'linguee',
#  ...]

# %%
# parse each xml file and generate a df
import xml.etree.ElementTree as etree
def xml_to_df(file, doc_type = 'pp'):
#     print(file)
    e = etree.parse(file)
    text = [e.findall('.//SUBTEXT')[i].text for i in range(len(e.findall('.//SECTION')))]
    sec_title = [e.findall('.//SUBTITLE')[i].text for i in range(len(e.findall('.//SECTION')))]
    policy_doc = {'file':file, 'text': text, 'title': sec_title}    
    df = pd.DataFrame({'file':file, 'section':sec_title, 'text': text, 'type':doc_type})
    return df

# %%
# Process xml privacy files
pp_xml_docs = [ ]
for file in pp_xml_files:
    parsed_file = xml_to_df(file, doc_type = '')
    pp_xml_docs.append(parsed_file)

pp_xml_df = pd.concat(pp_xml_docs, axis = 0)    
# pp_xml_docs = pd.concat(pp_xml_df)
pp_xml_df = pp_xml_df.reset_index()
pp_xml_df.head(15)
dump(df, open("/Users/dbm/Documents/Insight S19/data/acl_privacy_policy.pkl", "wb"))

# %%
# Read in files and do preliminary preprocessing
def read_html(file, pat = '[^a-zA-z0-9.?!/ ]+', filt_len=6, doc_type='pp'):
    html_file = open(file, 'r', errors='ignore')
    source_code = html_file.read()
    soup = BeautifulSoup(source_code, 'html.parser')
    tmp = sent_tokenize(''.join(soup.findAll(text=True)))
    tmp_sent = [re.sub(pat, '', i).rstrip() for i in tmp]
    tmp_sent = [
        re.sub(pattern='[ \t]{2,}', repl=' ', string=i) for i in tmp_sent
        if len(i) > filt_len
    ]
    txt = ' '.join(tmp_sent)
#     named_entities.append(get_named_entities(txt))
    try:
        year = re.search(string=txt, pattern='20\d{2}').group()
    except AttributeError:
        year = ''  # apply your error handling
        type(year)
    data = {'file': file, 'year': year, 'doc_type': doc_type, 'text': txt}
    return data

# %%
# load spacy pretrained model for Named Entity Recognition
# nlp = spacy.load('en_core_web_sm')
# named_entities = []
# def get_named_entities(text):
#     doc = nlp(text)
#     # Get organization name from text
#     org_names = np.unique([ent.text for ent in doc.ents if ent.label_ == 'ORG'])
#     return org_names

# %%
# tokenize, lower case, and lemmatize words
def tokenize(series, stop_words, frequent_words):
    return (
        series
        .apply(lambda x: simple_preprocess(x))
        .apply(lambda tokens: [token for token in tokens if token not in stop_words])
        .apply(lambda tokens: [token for token in tokens if token not in frequent_words])
#         .apply(lambda tokens: [token for token in tokens if token not in get_named_entities(tokens)])
        .apply(lambda tokens: [wnl.lemmatize(token) for token in tokens])
        .apply(lambda tokens: [token for token in tokens if len(token) > 3])
    )

# %%
# %%time
pp = [read_html(file=file, doc_type='pp') for file in pp_files]
oo = [read_html(file=file, doc_type='oo') for file in oo_files]

print(
    f'No. of Privacy policy Documents: {len(pp)} \nNo. of Opt out policy Documents: {len(oo)}'
)
# Out:
# No. of Privacy policy Documents: 115
# No. of Opt out policy Documents: 114
# CPU times: user 2.4 s, sys: 47.7 ms, total: 2.45 s
# Wall time: 2.53 s

# %%
# Combine data into dataframe
df = pd.DataFrame(pp+oo)
df.head(1)
# Out:
#   doc_type                                               file  \
# 0       pp  /Users/dbm/Downloads/OPP-115/sanitized_policie...
#
#                                                 text  year
# 0  Privacy Policy Last Modified March 25 2013 Thi...  2013

# %%
# %%time
# named_entities = [get_named_entities(i) for i in df['text']]
# named_entities = [i.split()for i in named_entities]
# Out:
# CPU times: user 4min 30s, sys: 35.4 s, total: 5min 6s
# Wall time: 1min 18s

# %%
# Save dataset
dump(df, open("/Users/dbm/Documents/Insight S19/data/privacy_optout_policy_1.pkl", "wb"))

# %%
# Words to filter
stop_words = set(stopwords.words('english'))
frequent_words = [
    'privacy', 'policy', 'andor', 'terms', 'service', 
    'please', 'valve','jibjab', 'steam', 'microsoft'
]
frequent_words.append(co_names)
# Initialize lemmatizer
wnl = WordNetLemmatizer()

# %%
# %%time
# Clean, lemmatize, and tokenize text
data_words = tokenize(df['text'], stop_words=stop_words,
                      frequent_words=frequent_words)
data_words = [' '.join(word) for word in data_words]
print(f'type: {type(data_words)}, len: {len(data_words)}')
# Out:
# type: <class 'list'>, len: 229
# CPU times: user 4.03 s, sys: 108 ms, total: 4.13 s
# Wall time: 4.17 s

# %%
data_words[0]
# Out:
# 'last modified march latinpost site intended explain practice cover following area applies governing safe harbor collection personal information information wireless marketing service associated promotional opportunity optingout certain personal information information wireless marketing service associated promotional opportunity wireless marketing service associated promotional opportunity sharing disclosure personal information information reviewing updating deleting certain information protection information california right change notice miscellaneous applies applies whether accessing site personal computer mobile device technology device known hereafter developed discovered device whether accessing site registered user offered site user site governs personal information information defined collected site cover information collected manner parent company subsidiary affiliate parent company collectively affiliate collected company unless specifically stated time time combine information term defined information collect source information received parent company affiliate marketing company advertiser resulting combined information subject remain full force effect even participation site particular feature function promotional activity offered site terminates expires cease suspended deactivated reason agree participate site feature activity service offered site governing safe harbor site designed targeted audience governed operated accordance make representation site operated accordance regulation governed nation participating site activity certify meet eligibility requirement site forth agreement meet eligibility requirement discontinue using site immediately continued site indicates agreeing collection disclosure management storage information described located outside european economic area switzerland site risk initiative responsible compliance applicable local national site part flux platform using site participating site activity providing personal information information consent transfer processing information provide site flux acknowledge provide lower standard protection personal data location understand site flux collect transfer store process deal information accordance flux consequently full extent permitted hereby waive claim relating processing personal information information accordance arise regulation apply country jurisdiction collection personal information information wireless marketing service associated promotional opportunity term personal information mean information would allow someone identify contact full name postal address email address telephone number term information mean information personal information collected personal information information together information information collect provide user registration extent offer user registration site register member site required select user name password together user required also provide information email address date birth additional information requested registration process required connection certain feature function also provide access certain feature function offer site option subscribe selection free email newsletter periodic information chat room message board electronic mail service messaging service auction shopping registration member profile page sign participate feature function required provide certain information order personalize allow feature function example sign receive email newsletter required provide email address date birth code separate user registration example extent offer service order various product defined agreement addition name contact information also collect maintain billing address shipping address product selection credit card payment instrument information order number information computer internet address website referred directed site referring credit card debit card number collected secure transmission connection promotion contest sweepstakes separate registration process enter promotion contest sweepstak ...

# %%
## Save dataset
dump(data_words, open("/Users/dbm/Documents/Insight S19/data/privacy_optout_policy_cleaned_1.pkl", "wb"))

# %%
##### References
- Inproceedings (ramanath:2014,
    author = {Rohan Ramanath and Fei Liu and Norman Sadeh and Noah Smith},
    booktitle = {Proceedings of ACL},
    month = {June},
    publisher = {Association for Computational Linguistics},
    title = {Unsupervised Alignment of Privacy Policies using Hidden Markov Models},
    year = {2014})
# Out:
#   File "<ipython-input-136-a678a33de3c7>", line 2
#     - Inproceedings (ramanath:2014,
#                              ^
# SyntaxError: invalid syntax
