# %% [markdown]
# # Preprocessing privacy and opt-out policies

# %%
# general imports
import warnings
import nltk
import pandas as pd
import numpy as np
import scipy as sp
from time import time, sleep
import json
import requests
import random
import os
import matplotlib.pyplot as plt
import re
from xml.etree import cElementTree as ET
from sklearn.externals import joblib
# Clean and lemmatize text
from nltk.corpus import stopwords
from gensim.utils import smart_open, simple_preprocess
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.tokenize import sent_tokenize, word_tokenize
import html5lib
import re
from bs4 import BeautifulSoup
import requests
from pprint import pprint
from pickle import dump,load
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
from pprint import pprint

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt

# Enable logging for gensim - optional
import logging
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

warnings.filterwarnings("ignore", category=DeprecationWarning)

random.seed(0)
# %matplotlib inline

# %%
# Directory paths
pp_dir = '/Users/dbm/Downloads/OPP-115/sanitized_policies/'
oo_dir = '/Users/dbm/Downloads/OptOutChoice-2017_v1.0/SanitizedPrivacyPolicies/'

# %%
# Read in all story files
def ls_fullpath(directory):
    return [os.path.join(directory, f) for f in os.listdir(directory)]

# %%
def extract_co_name(file, pat='\d+_|\.com|\.edu|\.html|\.xml|www_|_co'):
    co_name = re.sub(pattern=pat, repl='', string=os.path.basename(file))
    return co_name

# %%
# Read in files
pp_files = ls_fullpath(directory=pp_dir)
oo_files = ls_fullpath(directory=oo_dir)
oo_files = [i for i in oo_files if '.DS_Store' not in i]
# print(pp_xml_files)

# %%
# Extract company names from filenames
co_names_pp = [extract_co_name(file=file) for file in pp_files]
co_names_oo = [extract_co_name(file=file) for file in oo_files]
co_names_ppxml = [extract_co_name(file=file) for file in pp_xml_files]
co_names = co_names_pp + co_names_oo + co_names_ppxml

# %%
file = pp_xml_files[0]
doc_type = 'pp'
# df ={}
e = etree.parse(file)
text = [e.findall('.//SUBTEXT')[i].text for i in range(len(e.findall('.//SECTION')))]
text = [i for i in text if i is not None]
tmp = sent_tokenize(text[0])
tmp = ' '.join(tmp[1:])
tmp1 = [tmp] + text[1:]
' '.join(tmp1)

# sec_title = [e.findall('.//SUBTITLE')[i].text for i in range(len(e.findall('.//SECTION')))]
#     policy_doc = {'file':file, 'text': text, 'title': sec_title}    
# df = {'file':file, 'text': text, 'type':doc_type}
# df = pd.DataFrame(df)
# df = pd.DataFrame({'file':file, 'section':sec_title, 'text': text, 'type':doc_type})
# df
# text
# file
# pd.DataFrame.from_dict(df)
# Out:
# "When you share information with us, for example by creating a Google Account, we can make those services even better – to show you more relevant search results and ads, to help you connect with people or to make sharing with others quicker and easier. As you use our services, we want you to be clear how we're using information and the ways in which you can protect your privacy. Our Privacy Policy explains:\n\nWhat information we collect and why we collect it. How we use that information. The choices we offer, including how to access and update information. We've tried to keep it as simple as possible, but if you're not familiar with terms like cookies, IP addresses, pixel tags and browsers, then read about these key terms first. Your privacy matters to Google so whether you are new to Google or a long-time user, please do take the time to get to know our practices – and if you have any questions consult this page. We collect information to provide better services to all of our users – from figuring out basic stuff like which language you speak, to more complex things like which ads you'll find most useful or the people who matter most to you online.\n\nWe collect information in two ways:\n\nInformation you give us. For example, many of our services require you to sign up for a Google Account. When you do, we'll ask for personal information, like your name, email address, telephone number or credit card. If you want to take full advantage of the sharing features we offer, we might also ask you to create a publicly visible Google Profile, which may include your name and photo.\n\nInformation we get from your use of our services. We may collect information about the services that you use and how you use them, like when you visit a website that uses our advertising services or you view and interact with our ads and content. This information includes:\n\nDevice information\n\nWe may collect device-specific information (such as your hardware model, operating system version, unique device identifiers, and mobile network information including phone number). Google may associate your device identifiers or phone number with your Google Account.\n\nLog information\n\nWhen you use our services or view content provided by Google, we may automatically collect and store certain information in server logs. This may include:\ndetails of how you used our service, such as your search queries.\ntelephony log information like your phone number, calling-party number, forwarding numbers, time and date of calls, duration of calls, SMS routing information and types of calls.\nInternet protocol address.\ndevice event information such as crashes, system activity, hardware settings, browser type, browser language, the date and time of your request and referral URL.\ncookies that may uniquely identify your browser or your Google Account.\n\nLocation information\n\nWhen you use a location-enabled Google service, we may collect and process information about your actual location, like GPS signals sent by a mobile device. We may also use various technologies to determine location, such as sensor data from your device that may, for example, provide information on nearby Wi-Fi access points and cell towers.\n\nUnique application numbers\n\nCertain services include a unique application number. This number and information about your installation (for example, the operating system type and application version number) may be sent to Google when you install or uninstall that service or when that service periodically contacts our servers, such as for automatic updates.\n\nLocal storage\n\nWe may collect and store information (including personal information) locally on your device using mechanisms such as browser web storage (including HTML 5) and application data caches.\n\nCookies and anonymous identifiers\n\nWe use various technologies to collect and store information when you visit a Google service, and this may include sending one or more cookies or anonymous id ...

# %%
# parse each xml file and generate a df
import xml.etree.ElementTree as etree
def xml_to_df(file, doc_type = 'pp'):
#     print(file)
    e = etree.parse(file)    
    text = [e.findall('.//SUBTEXT')[i].text for i in range(len(e.findall('.//SECTION')))]
    sec_title = [e.findall('.//SUBTITLE')[i].text for i in range(len(e.findall('.//SECTION')))]
    policy_doc = {'file':file, 'text': text, 'title': sec_title}    
    df = pd.DataFrame({'file':file, 'section':sec_title, 'text': text, 'type':doc_type})
    return df

def xml_to_df_nosec(file, doc_type = 'pp'):
#     print(file)
    e = etree.parse(file)
    text = [e.findall('.//SUBTEXT')[i].text for i in range(len(e.findall('.//SECTION')))]
    text = [i for i in text if i is not None]

# Filter out the first line which usually includes the dates and other info
    tmp = sent_tokenize(text[0])
    tmp = ' '.join(tmp[1:])    
    tmp1 = [tmp] + text[1:]
    tmp1 = ' '.join(tmp1)

#     Filter out the first sentence
    df = {'file':file,'text': tmp1, 'type':doc_type}
    return df

# %%
# Read in files and do preliminary preprocessing
def read_html(file, pat = '[^a-zA-z0-9.?!/ ]+', filt_len=6, doc_type='pp'):
    html_file = open(file, 'r', errors='ignore')
    source_code = html_file.read()
    soup = BeautifulSoup(source_code, 'html.parser')
    tmp = sent_tokenize(''.join(soup.findAll(text=True)))
    tmp_sent = [re.sub(pat, '', i).rstrip() for i in tmp]
    tmp_sent = [
        re.sub(pattern='[ \t]{2,}', repl=' ', string=i) for i in tmp_sent
        if len(i) > filt_len
    ]
    txt = ' '.join(tmp_sent)
#     named_entities.append(get_named_entities(txt))
    try:
        year = re.search(string=txt, pattern='20\d{2}').group()
    except AttributeError:
        year = ''  # apply your error handling
        type(year)
    data = {'file': file, 'year': year, 'doc_type': doc_type, 'text': txt}
    return data

# %%
# load spacy pretrained model for Named Entity Recognition
# nlp = spacy.load('en_core_web_sm')
# named_entities = []
# def get_named_entities(text):
#     doc = nlp(text)
#     # Get organization name from text
#     org_names = np.unique([ent.text for ent in doc.ents if ent.label_ == 'ORG'])
#     return org_names

# %%
# tokenize, lower case, and lemmatize words
def tokenize(series, stop_words, frequent_words):
    return (
        series
        .apply(lambda x: simple_preprocess(x))
        .apply(lambda tokens: [token for token in tokens if token not in stop_words])
        .apply(lambda tokens: [token for token in tokens if token not in frequent_words])
#         .apply(lambda tokens: [token for token in tokens if token not in get_named_entities(tokens)])
        .apply(lambda tokens: [wnl.lemmatize(token) for token in tokens])
        .apply(lambda tokens: [token for token in tokens if len(token) > 3])
    )

# %%
# %%time
pp = [read_html(file=file, doc_type='pp') for file in pp_files]
oo = [read_html(file=file, doc_type='oo') for file in oo_files]

print(
    f'No. of Privacy policy Documents: {len(pp)} \nNo. of Opt out policy Documents: {len(oo)}'
)
# Out:
# No. of Privacy policy Documents: 115
# No. of Opt out policy Documents: 114
# CPU times: user 2.4 s, sys: 47.7 ms, total: 2.45 s
# Wall time: 2.53 s

# %%
# Combine data into dataframe
df = pd.DataFrame(pp+oo)
df.head(1)
# Out:
#   doc_type                                               file  \
# 0       pp  /Users/dbm/Downloads/OPP-115/sanitized_policie...
#
#                                                 text  year
# 0  Privacy Policy Last Modified March 25 2013 Thi...  2013

# %%
# %%time
# named_entities = [get_named_entities(i) for i in df['text']]
# named_entities = [i.split()for i in named_entities]
# Out:
# CPU times: user 4min 30s, sys: 35.4 s, total: 5min 6s
# Wall time: 1min 18s

# %%
# Save dataset
dump(df, open("/Users/dbm/Documents/Insight S19/data/privacy_optout_policy.pkl", "wb"))
# dump(df, open("/Users/dbm/Documents/Insight S19/data/privacy_optout_policy_1.pkl", "wb"))

# %%
# Words to filter
stop_words = set(stopwords.words('english'))
frequent_words = [
    'privacy', 'profile', 'policy', 'andor', 'terms', 'service', 
    'please', 'valve','jibjab', 'steam', 'microsoft'
]
frequent_words = frequent_words + co_names
# Initialize lemmatizer
wnl = WordNetLemmatizer()

# %%
# %%time
# Clean, lemmatize, and tokenize text
data_words = tokenize(df['text'], stop_words=stop_words,
                      frequent_words=frequent_words)
data_words = [' '.join(word) for word in data_words]
print(f'type: {type(data_words)}, len: {len(data_words)}')
# Out:
# type: <class 'list'>, len: 229
# CPU times: user 17.7 s, sys: 32.6 ms, total: 17.7 s
# Wall time: 17.7 s

# %%
data_words[0]
# Out:
# 'last modified march site intended explain practice following area applies governing safe harbor collection personal information information wireless marketing service associated promotional opportunity optingout certain personal information information wireless marketing service associated promotional opportunity wireless marketing service associated promotional opportunity sharing disclosure personal information information reviewing updating deleting certain information protection information california right change notice miscellaneous applies applies whether accessing site personal computer mobile device technology device known hereafter developed discovered device whether accessing site registered user offered site user site governs personal information information defined collected site cover information collected manner parent company subsidiary affiliate parent company collectively affiliate collected company unless specifically stated time time combine information term defined information collect source information received parent company affiliate marketing company advertiser resulting combined information subject remain full force effect even participation site particular feature function promotional activity offered site terminates expires cease suspended deactivated reason agree participate site feature activity service offered site governing safe harbor site designed targeted audience governed operated accordance make representation site operated accordance regulation governed nation participating site activity certify meet eligibility requirement site forth agreement meet eligibility requirement discontinue using site immediately continued site indicates agreeing collection disclosure management storage information described located outside european economic area switzerland site risk initiative responsible compliance applicable local national site part flux platform using site participating site activity providing personal information information consent transfer processing information provide site flux acknowledge provide lower standard protection personal data location understand site flux collect transfer store process deal information accordance flux consequently full extent permitted hereby waive claim relating processing personal information information accordance arise regulation apply country jurisdiction collection personal information information wireless marketing service associated promotional opportunity term personal information mean information would allow someone identify contact full name postal address email address telephone number term information mean information personal information collected personal information information together information information collect provide user registration extent offer user registration site register member site required select user name password together user required also provide information email address date birth additional information requested registration process required connection certain feature function also provide access certain feature function offer site option subscribe selection free email newsletter periodic information chat room message board electronic mail service messaging service auction shopping registration member page sign participate feature function required provide certain information order personalize allow feature function example sign receive email newsletter required provide email address date birth code separate user registration example extent offer service order various product defined agreement addition name contact information also collect maintain billing address shipping address product selection credit card payment instrument information order number information computer internet address website referred directed site referring credit card debit card number collected secure transmission connection promotion contest sweepstakes separate registration process enter promotion contest sweepstakes require submission fo ...

# %% [markdown]
# ## ACL policy documents

# %%
# Process xml privacy files
pp_xml = '/Users/dbm/Downloads/corpus/'
pp_xml_files = ls_fullpath(directory=pp_xml)
pp_xml_files = [i for i in pp_xml_files if '.DS_Store' not in i]

# %%
# Parses out the xml and divides the document into sections
pp_xml_docs = [ ]
for file in pp_xml_files:
    parsed_file = xml_to_df(file, doc_type = 'pp')
    pp_xml_docs.append(parsed_file)

# Convert to dataframe
pp_xml_df = pd.concat(pp_xml_docs, axis = 0)    
pp_xml_df.head(2)

#  Filter out rows with missing text
print(pp_xml_df.info())
print(pp_xml_df.isna().sum())

pp_xml_df = pp_xml_df.reset_index(drop=True)
pp_xml_df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10538 entries, 0 to 4
# Data columns (total 4 columns):
# file       10538 non-null object
# section    9622 non-null object
# text       10501 non-null object
# type       10538 non-null object
# dtypes: object(4)
# memory usage: 411.6+ KB
# None
# file         0
# section    916
# text        37
# type         0
# dtype: int64
#                                                file                 section  \
# 0  /Users/dbm/Downloads/corpus/www_google_co_nz.xml                    None
# 1  /Users/dbm/Downloads/corpus/www_google_co_nz.xml  Information we collect
#
#                                                 text type
# 0  Privacy Policy\n\nLast modified: December 20, ...   pp
# 1  We collect information to provide better servi...   pp

# %%
# Parses the document and retains the whole document agnostic to sections
pp_xml_full_docs = [xml_to_df_nosec(file, doc_type = 'pp') for file in pp_xml_files]
pp_xml_full_df = pd.DataFrame(pp_xml_full_docs)
dump(pp_xml_full_df, open("/Users/dbm/Documents/Insight S19/data/acl_privacy_policy_full_docs.pkl", "wb"))
pp_xml_full_df.head(2)
# Out:
#                                                file  \
# 0  /Users/dbm/Downloads/corpus/www_google_co_nz.xml
# 1        /Users/dbm/Downloads/corpus/ibnlive_in.xml
#
#                                                 text type
# 0  When you share information with us, for exampl...   pp
# 1   Web18 recognizes the importance of protecting...   pp

# %%
# Clean, tokenize text
pp_full_doc_words = tokenize(pp_xml_full_df['text'], stop_words=stop_words,
                      frequent_words=frequent_words)

pp_full_doc_words = [' '.join(word) for word in pp_full_doc_words]
# pp_full_doc_words
print(f'type: {type(pp_full_doc_words)}, len: {len(pp_full_doc_words)}')
dump(pp_full_doc_words, open("/Users/dbm/Documents/Insight S19/data/acl_privacy_policy_full_doc_words.pkl", "wb"))
# Out:
# type: <class 'list'>, len: 1010

# %%
len([word for word in word_tokenize(re.sub('[^a-zA-Z ]+','',pp_xml_df['text'][0])) if word not in stop_words])
# Out:
# 106

# %%
# Filter out rows with missing text
# pp_xml_df[pp_xml_df['text'].isnull()]
pp_xml_df = pp_xml_df[pp_xml_df['text'].notnull()]
dump(pp_xml_df, open("/Users/dbm/Documents/Insight S19/data/acl_privacy_policy.pkl", "wb"))

# %%
print(pp_xml_df.shape)
# Filter out the Policy names
pp_df_text = pp_xml_df[pp_xml_df['section'].notnull()]
print(pp_df_text.shape)

# Retain policy id
pp_df_name = pp_xml_df[pp_xml_df['section'].isnull()]
print(pp_df_name.shape)
# Out:
# (10501, 5)
# (9585, 5)
# (916, 5)

# %%
pp_df_text.head(2)
# Out:
#    index                                              file  \
# 1      1  /Users/dbm/Downloads/corpus/www_google_co_nz.xml
# 2      2  /Users/dbm/Downloads/corpus/www_google_co_nz.xml
#
#                              section  \
# 1             Information we collect
# 2  How we use information we collect
#
#                                                 text type
# 1  We collect information to provide better servi...   pp
# 2  We use the information we collect from all of ...   pp

# %%
## Save dataset
dump(pp_df_text, open("/Users/dbm/Documents/Insight S19/data/privacy_policy_acl_text.pkl", "wb"))
dump(pp_df_name, open("/Users/dbm/Documents/Insight S19/data/privacy_policy_acl_title.pkl", "wb"))
# dump(data_words, open("/Users/dbm/Documents/Insight S19/data/privacy_optout_policy_cleaned_1.pkl", "wb"))

# %%
# Add the company names to frequent words
co_names_acl = pp_df_text['file'].apply(lambda x: extract_co_name(x)).unique()
co_names_acl = co_names_acl.tolist()
frequent_words = frequent_words + co_names_acl
frequent_words = list(set(frequent_words))
print(len(frequent_words))
frequent_words
# Out:
# 1122
# ['spanishdict',
#  'irishtimes',
#  'legal_us_ubm',
#  'abcnews.go',
#  'easybib',
#  'dictionary.reference',
#  'scrippsnetworksinteractive',
#  'tinyurl',
#  'gap',
#  'gamespress',
#  'cryptsy',
#  'help_ladbrokes',
#  'oxforddictionaries',
#  'bhphotovideo',
#  'miniclip',
#  'neopets',
#  'petfinder',
#  'business-standard',
#  'security_wmtransfer',
#  'utexas_edu',
#  'statcounter',
#  'livejournal',
#  'travelocity',
#  '6pm',
#  'nlm_nih_gov',
#  'usairways',
#  'eventbrite',
#  'yahoo',
#  'consumerreports_org',
#  'dslreports',
#  'ted',
#  'costco',
#  'subscription_timeinc',
#  'scientificamerican',
#  'uploaded_net',
#  'xscores',
#  'addictinggames',
#  'yale_edu',
#  'med_nyu_edu',
#  'cosmopolitan',
#  'earthkam.org',
#  'curezone_org',
#  'apa_org',
#  'classified_bdnews24',
#  'foreignpolicy',
#  'biomedcentral',
#  'ubergizmo',
#  'mmajunkie',
#  'foxsports',
#  'ypg',
#  'jcpenney',
#  'boxingscene',
#  'virtualtourist',
#  'discogs',
#  'edmunds',
#  'facebook',
#  'ironhorsevineyards',
#  'lonelyplanet',
#  'wikitravel.org',
#  'emirates',
#  'merriam-webster',
#  'metatalk_metafilter',
#  'dict_leo_org',
#  'cms_paypal',
#  't-mobile',
#  'archives',
#  'hemmings',
#  'tradedoubler',
#  'ap_org',
#  'randomhouse',
#  'allrecipes',
#  'aeropostale',
#  'jagex',
#  'ziffdavis',
#  'fotolia',
#  'megamillions',
#  'fandango',
#  'betfair',
#  'mtgox',
#  'cafemom',
#  'girlsgogames',
#  'usda_gov',
#  'nfl',
#  'pnc',
#  'babycenter',
#  'snopes',
#  'head-fi_org',
#  'dogbreedinfo',
#  'wnep',
#  'curse',
#  'bbb_org',
#  'samsung',
#  'chron',
#  'dynamic_focalprice',
#  'soundcloud',
#  'stlouisfed.org',
#  'walmart',
#  'utm_utoronto_ca',
#  'nickjr',
#  'yola',
#  'rt',
#  'takepart',
#  'lufthansa',
#  'bodybuilding',
#  'please',
#  'mlbtraderumors',
#  'autoblog',
#  'amazon_ca',
#  'expedia_ca',
#  'nintendo',
#  'communitycoffee',
#  'upenn_edu',
#  'newscientist',
#  'jw_org',
#  'roblox',
#  'bom_gov_au',
#  'scout',
#  'indianexpress',
#  'guardianlv',
#  'wsmv',
#  'cms_gov',
#  'ets_org',
#  'terms',
#  'basketball_realgm',
#  'ultimate-guitar',
#  'monsterindia',
#  'shape',
#  'conversion-metric_org',
#  'urbanoutfitters',
#  'wellness',
#  'fao_org',
#  'ibnlive_in',
#  'localbitcoins',
#  'amarujala',
#  'fatwallet',
#  'getresponse',
#  'weeklystandard',
#  'nist_gov',
#  'rediff',
#  'elance',
#  'lg',
#  'examiner',
#  'realtor_org',
#  'reference',
#  'vg247',
#  'dropbox',
#  'berkeley_edu',
#  'amazon_uk',
#  'digitalspy_uk',
#  'volvocars',
#  'cbc_ca',
#  'mindmeister',
#  'stumbleupon',
#  'about_shopzilla',
#  'company_wizards',
#  'priceline',
#  'italki',
#  'php_net',
#  'arsenal',
#  'digg',
#  'modcloth',
#  'aboutus_lego',
#  'in_match',
#  'nps_gov',
#  'info_yahoo',
#  'aeroflot_ru',
#  'loc.gov',
#  'steam',
#  'ana_jp',
#  'jamieoliver',
#  'csmonitor',
#  'theverge',
#  'spine-health',
#  'lowes',
#  'bet-at-home',
#  'oddschecker',
#  'mozilla_org',
#  'economistgroup',
#  'earthclinic',
#  'weightwatchers',
#  'topgear',
#  'google_ie',
#  'privacy_pch',
#  'edx_org',
#  'avvo',
#  'oprah',
#  'collegelumbia_edu',
#  'commbankm_au',
#  'southwest',
#  'qatarairways',
#  'linguee',
#  'myhomeremedies',
#  'wwwepa_gov',
#  'sporcle',
#  'porsche',
#  'topix',
#  '101greatgoals',
#  'kohls',
#  'postmedia',
#  'bestbuy',
#  'telegraph_uk',
#  'jal_jp',
#  'newsmax',
#  'boxofficemojo',
#  'webopedia',
#  'acs_org',
#  'wiki_xbmc_org',
#  'home_bt',
#  'fifa',
#  'profootballtalk_nbcsports',
#  'ewg_org',
#  'skype',
#  'tagged',
#  'lids',
#  'usatoday',
#  'dailyillini',
#  'cambridge_org',
#  'archive_org',
#  'shaadi',
#  'affutd',
#  'pro_bitcoincharts',
#  'shop_lego',
#  'vimeo',
#  'shopbop',
#  'marriott',
#  'shopspaceweather',
#  'fcbarcelona',
#  'sciencemag.org',
#  'post-gazette',
#  'becomegorgeous',
#  'salon',
#  'wine-searcher',
#  'basketball-reference',
#  'hasbro',
#  'gizmodo_in',
#  'cricbuzz',
#  'reverso_net',
#  'canadapost_ca',
#  'gmx',
#  'internetbrands',
#  'cathaypacific',
#  'hotels',
#  'livingsocial',
#  'kraftrecipes',
#  'stardoll',
#  'english_alarabiya_net',
#  'everydayhealth',
#  'theglobeandmail',
#  'whitepagescustomers',
#  'rollingstone',
#  'coursera_org',
#  'cincymuseum.org',
#  'zazzle',
#  'xmarks',
#  'chase',
#  'avforums',
#  'aweber',
#  'gwdocs',
#  'zillow',
#  'marketwatch',
#  'fark',
#  'adorama',
#  'nationalreview',
#  'theonion',
#  'agb_traviangames',
#  'mcafee',
#  'vitals',
#  'enjin',
#  'shop_mercola',
#  'familysearch_org',
#  'military',
#  'forexfactory',
#  '4shared',
#  'horoscope',
#  'hbs_edu',
#  'privacy_ufl_edu',
#  'pages_ebay',
#  'istockphoto',
#  'mlb_mlb',
#  'incisivemedia',
#  'mapsofindia',
#  'nytimes',
#  'timeout',
#  'support_paddypower',
#  'lynda',
#  'translator_babylon',
#  'vistaprint',
#  'drinksmixer',
#  'dell',
#  'about_deviantart',
#  'bitstamp_net',
#  'allmusic',
#  'shareasale',
#  'nic_in',
#  'usa_canon',
#  'booking',
#  'ea',
#  'patient_uk',
#  'joomla_org',
#  'greenmangaming',
#  'inside_monster',
#  'bls_gov',
#  'howstuffworks',
#  'carfax',
#  'gamestop',
#  'si',
#  'superpages',
#  'pricegrabber',
#  'irs_gov',
#  'metoffice_gov_uk',
#  'alibaba',
#  'popsci',
#  'frys',
#  'freerepublic',
#  'sitepoint',
#  'liverpoolfc',
#  'staples',
#  'medscape',
#  'corporate_mediabistro',
#  'voanews',
#  'corporate_mattel',
#  'wwe',
#  'myfantasyleague',
#  'adobe',
#  'dnaindia',
#  'theatlantic',
#  'msn_foxsports',
#  'redbull',
#  'rapgenius',
#  'geocaching',
#  'drugstore',
#  'hostelbookers',
#  'pokemon',
#  'blog_feedly',
#  'privacy',
#  'apple',
#  'qvc',
#  'googlem_au',
#  'linkedin',
#  'usa.gov',
#  'media_townhall',
#  'sutterhealth_org',
#  'cambridgeindia_org',
#  'slashdotmedia',
#  'group_bmj',
#  'cvs',
#  'philly',
#  'hattrick_org',
#  'disneyprivacycenter',
#  'agoda',
#  'indeed_in',
#  'amazon_jp',
#  'cuny_edu',
#  'support_scribd',
#  'bloomberg',
#  'highgearmedia',
#  'na_square-enix',
#  'variety',
#  'skyscrapercity',
#  'playstation',
#  'socialsecurity_gov',
#  '192',
#  'nba',
#  'cabelas',
#  'bellasugar',
#  'usnews',
#  'help_marksandspencer',
#  'aenetworks',
#  'beta_opendns',
#  'gsmarena',
#  'vikings',
#  'thefreedictionary',
#  'wnd',
#  'capitalone',
#  'imperiaonline_org',
#  'fodors',
#  'dhl',
#  'netcarshow',
#  'chillingeffects_org',
#  'sea_blizzard',
#  'fedex',
#  'datehookup',
#  'fiverr',
#  'sites.google',
#  'companieshouse_gov_uk',
#  'bleacherreport',
#  'flamingtext',
#  'ksl',
#  'thestar',
#  'medicinenet',
#  'wwwhp',
#  'uptodate',
#  'un_org',
#  'futureshop_ca',
#  'info_sciencedirect',
#  'wwcox',
#  'bedbathandbeyond',
#  'cbsinteractive',
#  'careerbuilder',
#  'bankrate',
#  'bitpay',
#  'foxnews',
#  'moneycontrol',
#  'aafp_org',
#  'azlyrics',
#  'worldcarfans',
#  'dw_de',
#  'activenetwork',
#  'popularmechanics',
#  'sprint',
#  'complex',
#  'forbes',
#  'score_org',
#  'blockchain_info',
#  'zappos',
#  'allstate',
#  'n4g',
#  'stubhub',
#  'target',
#  'auspostm_au',
#  'ajc',
#  'ticketmaster',
#  'cbsi_secure_force',
#  'nejm_org',
#  'restaurantnews',
#  'htmlgoodies',
#  'espn_go',
#  'wikimediafoundation_org',
#  'sheknows',
#  'zocdoc',
#  'nydailynews',
#  'duolingo',
#  'biblegateway',
#  'collegehumor',
#  'sciencedaily',
#  'nationalgeographic',
#  'ndtv',
#  'slideshare_net',
#  'interpals_net',
#  'nhs_uk',
#  'landsend',
#  'honda',
#  'foursquare',
#  'in_godaddy',
#  'washingtonian',
#  'primagames',
#  'ar15',
#  'hotwire',
#  'theguardian',
#  'zenimax',
#  'products_butterflylabs',
#  'virgin-atlantic',
#  'shabdkosh',
#  'ebog',
#  'pbs_org',
#  'dol_gov',
#  'copyscape',
#  'behance_net',
#  'pearsoned',
#  'help_bet365',
#  'sfgate',
#  'usbank',
#  'flightradar24',
#  'sephora',
#  'easycalculation',
#  'nvidia',
#  'psychologytoday',
#  'hrs_de',
#  'fineartamerica',
#  'dx',
#  'mailchimp',
#  'web_worldbank_org',
#  'thehindu',
#  'tos_ea',
#  'thecarconnection',
#  'msn',
#  'britishairways',
#  'bibsonomy_org',
#  'pandora',
#  'laterooms',
#  'videogamernetwork',
#  'kia',
#  'myfico',
#  'macmillandictionary',
#  'jobdiagnosis',
#  'azcentral',
#  'enthusiastnetwork',
#  'flipkart',
#  'tonyrobbins',
#  'daveramsey',
#  'formula1',
#  'futureus',
#  'alexa',
#  'indianrail_gov_in',
#  'nbcuni',
#  'om_yr_no',
#  'elsevier',
#  'more_starfall',
#  'breitbart',
#  'about_usps',
#  'bellmedia_ca',
#  'disney_in',
#  'turkishairlines',
#  'alternet_org',
#  'cnbc',
#  'forums_xkcd',
#  'yelp',
#  'news.yahoo',
#  'purdue_edu',
#  'tomshardware',
#  'bankofamerica',
#  'help_overstock',
#  'classmates',
#  'iherb',
#  'speedtest_net',
#  'dairyqueen',
#  'gamerankings',
#  'netdoctor_uk',
#  'yardbarker',
#  'na_leagueoflegends',
#  'cartoonnetwork',
#  'mirror_uk',
#  'potterybarn',
#  'profile',
#  'chicagomarathon',
#  'conduit',
#  'constantcontact',
#  'bgr',
#  'legacy',
#  'europe_cnn',
#  'funtrivia',
#  'att',
#  'wwjustanswer',
#  'surfline',
#  'coolmath',
#  'hse_gov_uk',
#  'sears',
#  'abita',
#  'jpost',
#  'saksfifthavenue',
#  'nbc',
#  'jibjab',
#  'thesaurus',
#  'colorado_edu',
#  'care',
#  'webcrawler',
#  'security_berkeley_edu',
#  'salesforce',
#  'wiki_openstreetmap_org',
#  'manutd',
#  'instagram',
#  'icicibank',
#  'post_japanpost_jp',
#  'education.jlab.org',
#  'flalottery',
#  'automattic',
#  'ratemyprofessors',
#  'ups',
#  'fixya',
#  'victoriassecret',
#  'nuance',
#  'hulu',
#  'zedo',
#  'hollywoodlife',
#  'valve',
#  'info_doccheck',
#  'customerservice_macys',
#  'help_play',
#  'activision',
#  'dailykos',
#  'aaos_org',
#  'reuters',
#  'investopedia',
#  'axisbank',
#  'privacy_tribune',
#  'mathsisfun',
#  'codecademy',
#  'newsm_au',
#  'christianpost',
#  'nih_gov',
#  'saudiairlines',
#  'anticlown',
#  'brainyquote',
#  'barnesandnoble',
#  'wunderground',
#  'paulaschoice',
#  'mnn',
#  'usgs_gov',
#  'gearslutz',
#  'infowars',
#  'kayak_in',
#  'usa_autodesk',
#  'flashscore',
#  'pixmania_uk',
#  'loc_gov',
#  'freep',
#  'vitacost',
#  'cdc_gov',
#  'tangeroutlet',
#  'timeinc',
#  'artofmanliness',
#  'neworleansonline',
#  'rawstory',
#  'acidcow',
#  'egotastic',
#  'newsnow_uk',
#  'zomato',
#  'ucsd_edu',
#  'abovetopsecret',
#  'findagrave',
#  'planetminecraft',
#  'pillsbury',
#  'sitesell',
#  'shop_nordstrom',
#  'fool',
#  'southernsavers',
#  'cj',
#  'psu_edu',
#  'usaa',
#  'ezinearticles',
#  'studentdoctor_net',
#  'portal_lacaixa_es',
#  'sbnation',
#  'ucdavis_edu',
#  'mapsofworld',
#  'abcnews',
#  'austincc',
#  'essence',
#  'ideas.repec.org',
#  'ae',
#  'espncricinfo',
#  'williamhill_us',
#  'minecraft.gamepedia',
#  'archives.gov',
#  'gocomics',
#  'couchsurfing_org',
#  'ucla_edu',
#  'care2',
#  'bitcoin_org',
#  'privacy_aol',
#  'airberlin',
#  'advance_net',
#  'foodallergy.org',
#  'harvard_edu',
#  'lifehack_org',
#  'pinkbike',
#  'xing',
#  'noaa_gov',
#  'nhl',
#  'legal_kinja',
#  'who_int',
#  'thekitchn',
#  'gametrailers',
#  'apartmenttherapy',
#  'blackboard',
#  'dreamstime',
#  '888',
#  'patents_uspto_gov',
#  'kaleidahealth.org',
#  'reddit',
#  'babylon',
#  'imdb',
#  'kmart',
#  'hopkinsmedicine_org',
#  'nypost',
#  'mylife',
#  'eatingwell',
#  'amazon',
#  'webmd',
#  'help-all_nike',
#  'sltrib',
#  'bulbapedia_bulbagarden_net',
#  'airliners_net',
#  'google',
#  'disinfo',
#  'corporate_walmart',
#  'account_ankama',
#  'wisegeek',
#  'perfectworld',
#  'independent_uk',
#  'ifsa-butler.org',
#  'prnewswire_mediaroom',
#  'aa',
#  'onlineconversion',
#  'williams-sonoma',
#  'gm',
#  'admin_ox_ac_uk',
#  'couponsinc',
#  'meredith',
#  'thestudentroom_uk',
#  'petsmart',
#  'newgrounds',
#  'en_mappy',
#  'redbubble',
#  'washington_edu',
#  'policy',
#  'google_uk',
#  'weebly',
#  'freelotto',
#  'hollywoodreporter',
#  'nbcuniversal',
#  'nutrition_org',
#  'listal',
#  'paypal',
#  'astrom_my',
#  'money_cnn',
#  'marthastewart',
#  'glispa',
#  'southparkstudios',
#  'latinpost',
#  'craigslist_org',
#  'about_ask',
#  'homedepot',
#  'yoox',
#  'cpsc_gov',
#  'pages_ebay_in',
#  'about_abc_net_au',
#  'lotterypost',
#  'behindthename',
#  'nature',
#  'mobile9',
#  'newsbusters.org',
#  'covers',
#  'muscleandfitness',
#  'mtv',
#  'fredericknewspost',
#  'sharecare',
#  'google_in',
#  'intermarkets_net',
#  'accuweather',
#  'nelsonmandela_org',
#  'officedepot',
#  'forever21',
#  'petmd',
#  'hostelworld',
#  'bounty',
#  'cariboucoffee',
#  'fortune',
#  'nick',
#  'service_prweb',
#  'wordreference',
#  'hostgator',
#  'last_fm',
#  'warnerbros',
#  'ehow',
#  'teamliquid_net',
#  'motortrend',
#  'ivillage',
#  'tigerdirect',
#  'naturallycurly',
#  'jpl_nasa_gov',
#  'popsugar',
#  'census_gov',
#  'gawker',
#  'sulekha',
#  'intel_in',
#  'phoenix_edu',
#  'sports-reference',
#  'mixedmartialarts',
#  'hindustantimes',
#  'salemwebnetwork',
#  'walgreens',
#  'expatriates',
#  'reviewcentre',
#  'asos',
#  'm_ciao_de',
#  'destructoid',
#  'newsbusters_org',
#  'acbj',
#  'styleforum_net',
#  'craveonline',
#  'kbb',
#  'drweil',
#  'secure_avaaz_org',
#  'imageshack_us',
#  'timeanddate',
#  'yardbraker',
#  'badoo',
#  'photobucket',
#  'fda_gov',
#  'retailmenot',
#  'wellsfargo',
#  'hsn',
#  'pages_ebaym_au',
#  'indiatimes',
#  'dynamicdrive',
#  'usa_gov',
#  'sec_gov',
#  'healthcare_gov',
#  'sidearmsports',
#  'about',
#  'tmz',
#  'tgifridays',
#  'goodreads',
#  'mohegansun',
#  'solarviews',
#  'thehill',
#  'stackexchange',
#  'bradsdeals',
#  'peoplesmart',
#  'rxlist',
#  'mensfitness',
#  'autosport',
#  'ocregister',
#  'avg',
#  'mashable',
#  'cooks',
#  'career_sdsu_edu',
#  'nextag',
#  'udemy',
#  'iberia',
#  'niddk_nih_gov',
#  'alaskaair',
#  'wordpress_org',
#  'christianbook',
#  'cancer_org',
#  'intellicast',
#  'alz_org',
#  'sci-news',
#  'delta',
#  'help_ft',
#  'gameinformer',
#  'redorbit',
#  'aircanada',
#  'udacity',
#  'livescore',
#  'sciencemag_org',
#  'fema_gov',
#  'oclc_org',
#  'integrativenutrition',
#  'blackfriday',
#  'signup_netflix',
#  'coolmath-games',
#  'corporate_discovery',
#  'indianrailways_gov_in',
#  'edition_cnn',
#  'rockstargames',
#  'taylorswift',
#  'help_kijiji_net',
#  'uspto_gov',
#  'pegym',
#  'online_citibank',
#  'ibtimes',
#  'net-a-porter',
#  'canada_ca',
#  'liquor',
#  'en_wikipedia_org',
#  'bitly',
#  'yourdictionary',
#  'slate',
#  'spotify',
#  'mediafire',
#  'valueclickmedia',
#  'pages_ebay_uk',
#  'comcast',
#  'nbcnews',
#  'privacy_microsoft',
#  'rackspace',
#  'state_gov',
#  'urbandictionary',
#  'plannedparenthood_org',
#  'researchgate_net',
#  'trulia',
#  '123rf',
#  'qantasm_au',
#  'wiki_answers',
#  'fairfaxm_au',
#  'caranddriver',
#  'help_sky',
#  'online-sweepstakes',
#  'gsb_stanford_edu',
#  'worg',
#  'vrbo',
#  'americanexpress',
#  'cars',
#  'easyjet',
#  'surveymonkey',
#  'as_wiley',
#  'boardgamegeek',
#  'us_playstation',
#  'opentable',
#  'anthropologie',
#  'rei',
#  'travelzoo',
#  'tulsaworld',
#  'aarp_org',
#  'klm',
#  'royalmail',
#  'irctc_in',
#  'buffalowildwings',
#  'washingtonpost',
#  'amexpub',
#  't-nation',
#  'citizen.org',
#  'pbskids_org',
#  'weather_gov',
#  'ford',
#  'jcrew',
#  'en_bitcoin_it',
#  'zendesk',
#  'consumerist',
#  'calottery',
#  'mmorpg',
#  '24hourfitness',
#  'webdeveloper',
#  'wisc_edu',
#  'europa_eu',
#  'toysrus',
#  'huffingtonpost',
#  'socialanxietysupport',
#  'stevepavlina',
#  'imgur',
#  'diabetes_org',
#  'freelancer',
#  'accounts_clickbank',
#  'domaintools',
#  'hairfinder',
#  'cancer_gov',
#  'cracked',
#  'vegasinsider',
#  'google_nz',
#  'quikr',
#  'digitaltrends',
#  'newegg',
#  'about_officemax',
#  'bettycrocker',
#  'jstor_org',
#  'skyscanner_in',
#  'metacafe',
#  'td',
#  'hootsuite',
#  'techmedianetwork',
#  'ebaumsworld',
#  'wikia',
#  'whitehouse_gov',
#  'uefa',
#  'btc-e',
#  'arabic-keyboard_org',
#  'eonline',
#  'pbs.org',
#  'coffeereview',
#  'ca_gov',
#  'shopathome',
#  'wedding_theknot',
#  'unwomen_org',
#  'meetup',
#  'store.steampowered',
#  'groupon',
#  'eatchicken',
#  'united',
#  'llbean',
#  'bbc_uk',
#  'newsvine',
#  'mathrubhumi',
#  'besthealthmag_ca',
#  'homeaway',
#  'adweek',
#  'about_pinterest',
#  'neimanmarcus',
#  'hm',
#  'company_findlaw',
#  'nationalzoo.si',
#  'simplyrecipes',
#  'samsclub',
#  'ieee_org',
#  'cheaptickets',
#  'wowhead',
#  'rhymezone',
#  'ubi',
#  'privacy_sourceinterlinkmedia',
#  'entrepreneur',
#  'help_github',
#  'corporate_britannica',
#  'zacks',
#  'creativecommons_org',
#  'wowwiki',
#  'heavy',
#  'www.loc.gov',
#  'correiosm_br',
#  'lodgemfg',
#  'dailynews',
#  'chasepaymentech',
#  'steampowered',
#  'totalbeauty',
#  'lds_org',
#  'opensecrets.org',
#  'weather',
#  'fanfiction_net',
#  'wwwed_gov',
#  'lumosity',
#  'ikea',
#  'miaminewtimes',
#  'soccervista',
#  'drrobertrey',
#  'codeschool',
#  'futureplc',
#  'cafepress',
#  '000webhost',
#  'dcccd',
#  'radioshack',
#  ...]

# %%
# Clean, tokenize text
pp_data_words = tokenize(pp_df_text['text'], stop_words=stop_words,
                      frequent_words=frequent_words)

# %%
pp_data_words = [' '.join(word) for word in pp_data_words]
pp_data_words
print(f'type: {type(pp_data_words)}, len: {len(pp_data_words)}')
# Out:
# type: <class 'list'>, len: 9585

# %%
pp_data_words
# Out:
# ['collect information provide better service user figuring basic stuff like language speak thing like find useful people matter online collect information information give example many service require sign account personal information like name email address telephone number credit card want take full advantage sharing feature offer might also create publicly visible include name photo information service collect information service like visit website advertising service view interact content information includes device information collect device specific information hardware model operating system version unique device identifier mobile network information including phone number associate device identifier phone number account information service view content provided automatically collect store certain information server include detail used search query telephony information like phone number calling party number forwarding number time date call duration call routing information type call internet protocol address device event information crash system activity hardware setting browser type browser language date time request referral cooky uniquely identify browser account location information location enabled collect process information actual location like signal sent mobile device also various technology determine location sensor data device example provide information nearby access point cell tower unique application number certain service include unique application number number information installation example operating system type application version number sent install uninstall periodically contact server automatic update local storage collect store information including personal information locally device using mechanism browser storage including html application data cache cooky anonymous identifier various technology collect store information visit include sending cooky anonymous identifier device also cooky anonymous identifier interact service offer partner advertising service feature appear site',
#  'information collect service provide maintain protect improve develop protect user also information offer tailored content like giving relevant search result name provide across service offer require account addition replace past name associated account represented consistently across service user already email information identifies show publicly visible information name photo contact keep record communication help solve issue might facing email address inform service letting know upcoming change improvement information collected cooky technology like pixel improve user experience overall quality service example saving language preference able service appear language prefer showing tailored associate cookie anonymous identifier sensitive category based race religion sexual orientation health combine personal information information including personal information service example make easier share thing people know combine doubleclick cookie information personally identifiable information unless consent consent using information purpose process personal information server many country around world process personal information server located outside country live',
#  'people different concern goal clear information collect make meaningful choice used example review control certain type information tied account using dashboard view edit preference shown across category might interest using setting also certain advertising service editor adjust appears particular individual control share information take information many service also browser block cooky including cooky associated service indicate cookie however important remember many service function properly cooky disabled example remember language preference',
#  'many service share information others remember share information publicly indexable search engine including service provide different option sharing removing content',
#  'whenever service provide access personal information information wrong strive give update quickly delete unless keep information legitimate business legal purpose updating personal information verify identity request reject request unreasonably repetitive require technical effort example developing system fundamentally changing existing practice risk others would extremely impractical instance request concerning information residing backup system provide information access correction free except would require effort maintain service manner protects information accidental malicious destruction delete information service immediately delete residual copy active server remove information backup system',
#  'share personal information company organization individual outside unless following circumstance applies consent share personal information company organization individual outside consent require consent sharing sensitive personal information domain administrator account managed domain administrator example apps user domain administrator resellers provide user support organization access account information including email data domain administrator able view statistic regarding account like statistic regarding application install change account password suspend terminate account access access retain information stored part account receive account information order satisfy applicable regulation legal process enforceable governmental request restrict ability delete edit information setting refer domain administrator information external processing provide personal information affiliate trusted business person process based instruction compliance appropriate confidentiality security measure legal reason share personal information company organization individual outside good faith belief access preservation disclosure information reasonably necessary meet applicable regulation legal process enforceable governmental request enforce applicable including investigation potential violation detect prevent otherwise address fraud security technical issue protect harm right property safety user public required permitted share aggregated personally identifiable information publicly partner like publisher advertiser connected site example share information publicly show trend general service involved merger acquisition asset sale continue ensure confidentiality personal information give affected user notice personal information transferred becomes subject different',
#  'work hard protect user unauthorized access unauthorized alteration disclosure destruction information hold particular encrypt many service using offer step verification access account safe browsing feature chrome review information collection storage processing practice including physical security measure guard unauthorized access system restrict access personal information employee contractor agent need know information order process subject strict contractual confidentiality obligation disciplined terminated fail meet obligation',
#  'applies service offered affiliate including service offered site advertising service excludes service separate policy incorporate apply service offered company individual including product site displayed search result site include service site linked service cover information practice company organization advertise service cooky pixel technology serve offer relevant',
#  'regularly review compliance also adhere several self regulatory framework receive formal written complaint contact person made complaint follow work appropriate regulatory authority including local data protection authority resolve complaint regarding transfer personal data cannot resolve user directly',
#  'change time time reduce right without explicit consent post change page change significant provide prominent notice including certain service email notification change also keep prior version archive review',
#  'following notice explain specific practice respect certain product service chrome chrome book wallet fiber',
#  'recognizes importance protecting information keep information entrust safely securely',
#  'tell collect information protect share personal information provide site site unless otherwise specified relevant site different displayed apply practice company control people employ manage',
#  'respect visitor right personal collect information throughout site disclosed statement applies solely information collected ibnlive collect personally identifiable information including directly register site service enter competition prize draw navigate around site respond communication also receive personally identifiable information third party including related company business partner publicly available source information following normally collect help provide service personal attribute name address gender date birth email telephone number detail information website including detail domain name internet protocol address operating system browser cooky time spent page content route took navigate page data time time help provide improved product service choose provide certain information able provide particular also automatically receives record information server browser including address cookie information page requested addition service make personal information public post personal information online accessible public receive unsolicited message party return responsible misuse information main personal information verify identity help provide service administer service enable review improve provide access certain area website personalise visit site competition game assist advertising revenue generation function information collect also used notify visitor event change information site information collect never shared organization commercial purpose information used marketing agreed market research purpose including internal demographic study provide optimise personalise service send newsletter information agreed product service information create picture interest allow understand customer visitor better make service marketing relevant information include information site household classification data response communication interaction part group information provide register site customer survey information provided company gave permission share information technical method cooky beacon collate information section cooky information',
#  'disclose personally identifiable information third party except following situation consent share information need share information provide product requested need share information certain partner order respond comment resolve issue unless tell differently partner independent right information except respond comment resolve issue respond request indian foreign government security defence revenue regulatory authority agency officer respond subpoena court order legal proceeding required action necessary protect defend right property ibnlive applicable regulation requires disclosure information protect safety security user site find action site violate usage guideline specific product service sell business group company another organisation merge business case buyer able information third party processor administer process personal information purpose notified hosting activity related site service need share detail third party auditor legal advisor obtain advice processing governed agreement form required preserving statutory data protection right',
#  'share information member group used group includes holding limited cayman island subsidiary affiliated entity including company branded network label mean member group people disclose personal information include member related company advertiser content partner either aggregate form user clicked banner credit reporting fraud checking agency professional adviser including accountant auditor lawyer information provider disclosing individual record address required government regulatory authority organisation required authorised ensure people information perform function adequate procedure place deal data securely people based outside india',
#  'line permission give send direct marketing carefully selected third party good service disclose information organisation send direct marketing change marketing preference registered addition unsubscribe email communication unsubscribe link provided communication sent',
#  'mean providing useful resource user ibnlive provides link site carefully choose site believe useful meet high standard however site change quickly guarantee standard website link provide imply endorsement ibnlive responsible data policy content security website linked site aware site could directed site personal information collected outside control site govern information obtained site',
#  'access change information provided registration simply click link http ibnlive member name password wherever necessary instruction start page help recover password forgotten also contact mail clicking contact ibnlive page send email directly editor ibnlive include information mail help identify account assist inquiry request',
#  'collect information technology make site content service make available interesting useful instance come site computer medium device combine visitor session information information collected cooky beacon technical method personally identifiable information order understand improve online experience determine product promotion service prefer likely interest cooky piece information site sends computer medium device viewing interacting site cooky purpose including tracking usage site order enhance guest experience site learn preference interest beacon small piece data embedded image page site also technical method analyse traffic pattern site frequency user visit various part site ensures information collected accessed access cooky maintained accordance allows company presenting advertisement page access cooky computer company cooky subject policy advertiser company access cooky',
#  'take various precaution keep personal information secure unauthorized access store personal information long necessary provide service archive purpose responsible keeping user password secure disclose anyone',
#  'amend time time post latest version site ever wish personal information incompatible information consent',
#  'right access website conditional upon full acceptance accessing site signify consent store process personal data accordance',
#  'need assistance query personal information send email question comment editor ibnlive',
#  'treatment personally identifiable information collected universal uclick owned operated affiliated site sign service provided site cover information collected company site universal uclick control also guide behavior individual employed universal uclick',
#  'universal uclick sole owner information collected universal uclick personal information collected voluntarily provide',
#  'personal information individually identifiable information person information include first last name credit card number home billing mail address personal identifier reveals individual mail address telephone social security number personal information also includes persistent identifier customer number held cookie definition cookie identifier associated individually identifiable information customized experience universal uclick gather user information provide customized experience site service user information help tailor content service good advertising current future need reason register provide personal information visit certain area site register free service order product enter contest subscribe newsletter choose register access area require personal identification subscription service subscribe site premium content service universal uclick gather user information personal information grant access site universal uclick third party accept process order credit card purchase subscription merchandise product choose register access subscription area require personal identification mail delivery register site daily mail delivery subscription service purchase product time time mail informative message service third party product service believe interest feature service special offer updated information mail contain code enables database track usage mail including whether mail opened link clicked combine information information information improve site experience provide customized mail communication mobile messaging universal uclick might gather personal information specific participating mobile messaging program information requested include contact mobile phone number carrier model product delivery demographic information',
#  'register universal uclick asks mail address user selected user name information registered user update able provide additional preferential information member name nickname certain user preference universal uclick also optional information universal uclick respect child subscription service subscribe universal uclick asks mail address user selected user name password necessary financial information process order credit card information collected universal uclick however specific credit card number stored within universal uclick system contact information order used fulfill premium purchase registered user touch user deemed necessary subscribed user update able provide additional preferential information universal uclick also optional information universal uclick respect child order form product store universal uclick also order form user request information product service order form collect user contact information mail address necessary financial information process order credit card number contact information order used send order registered user touch user deemed necessary universal uclick third party accept process order credit card purchase merchandise product product third party host store page ordering system order data collect order information contact information necessary financial information process order policy site information information special contest promotion universal uclick occasionally present special contest promotion sponsored another company qualify entry contest promotion provide personal information plan share information sponsor others provide statement effect contest promotion location data device global positioning system location detection functionality collect precise information location device site application location information provide requested location service provide alternate functionality site application based location allowing access location data disabling device location detection functionality system address internet protocol address unique string number assigned computer internet provider server automatically identify computer address address help diagnose problem server administer site address also used gather broad demographic information cooky cookie small line text stored browser record keeping purpose help provide better browser option accept reject provide notice cookie sent universal uclick utilize cookie technology sending receiving information computer browser computer also cooky customize site deliver content specific interest computer generated information universal uclick server track movement site property addition information customize user experience provide registrant continuity various site property universal uclick also technology verify track certain service confirm receipt certain mailed product test integrity system product service advertisement appearing site delivered advertising partner process serving advertiser place cookie browser cookie file information excluding name address mail address personal information visit site order provide advertisement site site good service interest delivering site universal uclick able record user identified unique cookie seen universal uclick site page user viewing delivered usage information combined delivery information universal uclick type operating system computer collected visit universal uclick site site affiliated universal uclick personally identifiable information used part serving process reporting select direct online universal uclick site additionally generated third party serving system also place cookie browser provide usage information third party note advertiser asks show advertisement certain audience example audience segment example viewed sport content respond advertiser server conclude description audience trying reach always remember authorize third party server employ anonymous cooky delivery anonymous targeting third party server collect give access personally identifying information find speci ...
#  'share personally identifiable information third party aside entity perform service fulfilling order either bound comply policy protect information unless opted sharing previously opted sharing prior version still considered opted statement stated universal uclick third party accept process order merchandise product however universal uclick disclose information provide required good faith belief disclosure necessary comply legal process served universal uclick protect defend right property universal uclick emergency protect someone safety gather demographic information example education level household income time time share information manner identifies individual entity unless know time collection permission share demographic information third party give aggregate information develop business sell asset depending upon transaction personal information transferred asset event universal uclick acquired another company personal information part asset transferred acquiring party',
#  'ability request deletion universal uclick registration time utilizing registration system established purpose however maintain certain information part internal process prevent accidental loss user data information prevent discourage fraudulent activity involve universal uclick registration account information also continue maintain information registration account computer access site service part server unless mail information universal uclick including information selected third party want receive information universal uclick third party selected decline receive provide personal information universal uclick visit account page click update billing information updated setting also contact universal uclick postal mail address',
#  'universal uclick site general audience site directed child universal uclick assumes product purchased credit card mean purchased adult universal uclick respect parent child committed complying child online protection coppa area site universal uclick collect personal information individual identify except limited circumstance universal uclick belief collection permitted coppa universal uclick prospective user provide registration process area universal uclick site user indicates personal data collected registration process automatically deleted except universal uclick retain limited information child mail address limited period time case universal uclick belief collection information permitted coppa parent belief child submitted personal information universal uclick contact mail postal mail listed universal uclick promptly delete information upon learning relates child universal uclick belief parent supervise child online activity consider using parental control tool available online service software manufacturer help provide friendly online environment tool also prevent child otherwise disclosing online name address personal information without parental permission universal uclick commitment data security protecting user personal information high priority universal uclick best effort ensure security personal information universal uclick maintains physical electronic procedural safeguard comply federal regulation guard personal information exercise great providing secure transmission information computer unfortunately electronic communication internet guaranteed secure strive take great protect personal information cannot warrant security information submit risk also take precaution protect personal information line access user information restricted employee agent processor whose require accessing user personal information granted database access administrator level account server contain personal information finally server containing user personal information kept locked secure data center require secure login access remotely remember sign site close browser window finished using ensure others cannot pose online especially important terminal accessible others library school workplace internet café security universal uclick security measure place protect loss misuse alteration information control include firewall prevent unauthorized access system maintenance registration information separate database although exercise reasonable providing secure transmission information computer server cannot ensure warrant security information transmitted internet accept liability unintentional disclosure protect transmission credit card information industry standard secure socket layer encryption thawte server certificate offer secure communication encrypting data site thawte checked verified company registration document site registered domain name consumer guideline know whether site secure chat room public area universal uclick offer chat bulletin board public function posting considered public information available user posting governed universal uclick refer friend user elect referral informing friend site particular feature content friend name mail address universal uclick automatically send friend time email inviting visit universal uclick site universal uclick store information sole purpose sending time email friend contact universal uclick request removal information database personal information password protected take appropriate measure protect secrecy password computer public place share computer others remember sign close browser window finish session universal uclick order prevent others accessing personal information',
#  'help universal uclick maintain accuracy notifying change address phone number mail address time wish update information stop receiving communication universal uclick dashboard click account page click update billing information updated setting include contact information make appropriate correction contacting universal uclick universal uclick would like receive comment question statement address comment question regarding universal uclick statement mail postal mail complete mail form http help contact also contact universal uclick mail universal uclick attn universal uclick walnut kansa city acceptance statement universal uclick site including dispute concerning subject statement universal uclick condition using universal uclick site accepting practice statement condition reserve right modify statement time posting change page check revision date bottom page determine statement modified since last reviewed continued portion universal uclick site following posting updated statement constitute acceptance change updated',
#  'site content collective work comprising site including information article data software photograph graph video typeface graphic music sound artwork material collectively content protected copyright trademark patent proprietary right state international held original creator material including supplier affiliate site visitor contributing material connection community blog expert similar service site information contribution site content submission right valid protected form medium technology existing developed future bouncing ball design mark charity petperks among numerous trademark used site registered otherwise protected state canada international intellectual property trademark mark logo slogan domain name trade name property respective owner licensed otherwise used permission intellectual property used site reproduced copied otherwise manipulated manner without express written permission owner disclaims proprietary interest intellectual property',
#  'download content displayed site commercial personal provided also retain copyright trademark proprietary notice contained content alter content copy post content network computer broadcast content medium except expressly authorized herein authorized representative license strictly prohibits modifying transmitting distributing reusing reposting framing using content site site server including text image audio video public commercial purpose downloading image product sale within site strictly prohibited copy modify remove delete augment publish transmit participate transfer sale lease rental create derivative work exploit content site whole part',
#  'many opportunity contribute site using site agree information except purchase information send contribute site submit post display site confidential including data text photo video story article name first last fiction fiction information suggestion idea comment link send third party using site material submitting solicited unsolicited material using site grant irrevocable unrestricted license modify reproduce transmit display distribute material purpose whatsoever extent permitted submitting material community similar site agree sole owner copyright holder photo video story information submit item infringe intellectual property right individual entity including photographer took photo video submitted item contain material otherwise violates criminal prohibition grant employee agent personnel assigns licensee successor interest legal representative irrevocable perpetual royalty free right photo video story information name first name last name fictional name provided submission likeness form medium manner without restriction notice change alteration advertising promotion publicity lawful purpose material submit altered purpose proper publication waive claim based usage photo video story information release liability related distribution publication dissemination item including publication internet waive moral integrity right respect photo video submitted acknowledge relying upon would material submit absence liable responsible content provided user website sell right photo video story information third party sole discretion remove material determine unlawful fraudulent harassing offensive threatening libelous defamatory obscene otherwise objectionable infringes violates party intellectual property proprietary right notice policy includes comment concerning competitor vendor business partner provider associate affiliate liable responsible content provided user third party site contribution site third party necessarily represent view opinion preview user content appears site user held liable illegal prohibited user content provide site including among thing infringing defamatory offensive material discover kind material site promptly notify customercare investigate take appropriate action',
#  'site created controlled operated provider commerce solution state america state arizona govern site without giving effect principle conflict',
#  'site contains link site operated third party including third party site display trademark third party site link available convenience intended enable access third party site purpose warrant make representation substance quality functionality accuracy fitness particular purpose merchantability representation third party site content link third party site site constitute sponsorship endorsement approval responsibility third party site make representation warranty product service offered third party site condition legal notice third party site differ substantially notice policy apply site review condition third party site information condition apply third party site using site search link third party site agree understand make claim damage loss whatsoever resulting site obtain search result link third party site however problem link site know customercare investigate take appropriate action',
#  'information security practice site using site agree responsible maintaining confidentiality account password restricting access computer account accept responsibility activity occur account password access site public computer computer multiple people access follow relevant instruction sufficiently disconnect site computer system using prevent unauthorized access account unlawful activity site strictly prohibited includes tampering site misrepresenting identity user using buying agent conducting fraudulent activity site user prohibited violating attempting violate security site including without limitation accessing data intended user logging onto server account user authorized access using site unintended purpose trying change behavior site attempting probe scan test vulnerability system network breach security authentication measure without proper authorization attempting interfere user host network including without limitation mean submitting virus site overloading flooding spamming mailbombing crashing forging packet header part header information mail newsgroup posting forging communication behalf site impersonating site site impersonating legitimate user sending unsolicited unauthorized mail behalf including promotion advertising product service expressly prohibited violation system network security result civil criminal liability agree device software routing data interfere attempt interfere proper working site activity conducted site agree attempt engine software tool agent data device mechanism including browser spider robot avatar intelligent agent navigate search site search engine search agent provided publicly available browser content following type thing illegal prohibited site patently offensive online community content promotes racism bigotry hatred physical harm kind group individual could harmful minor including material exploit person sexual violent manner solicits personal information anyone provides instructional information illegal activity making buying illegal weapon violating someone providing creating computer virus solicits password personal identifying information commercial unlawful purpose user harasses advocate harassment another person display pornographic material kind involves transmission junk mail chain letter unsolicited mass mailing spamming promotes information know false misleading promotes illegal activity conduct abusive threatening obscene defamatory libelous promotes illegal unauthorized copy another person work providing pirated computer program link provides information circumvent manufacturer installed copy protect device provides pirated content link pirated content file contains restricted password access page hidden page image linked another accessible page engages commercial activity sale relating without prior written consent contest sweepstakes barter advertising pyramid scheme',
#  'certain software similar material software download site subject state export control software site downloaded exported contrary applicable export including applicable prohibition download export follows national resident cuba iran libya north korea syria country state embargoed good anyone state treasury department list specially designated national commerce department table deny order downloading using software downloaded site agree abide applicable rule regulation including export administration export control represent warrant transfer electronic transmission otherwise software foreign national foreign destination violation',
#  'agree indemnify hold officer agent employee partner harmless loss liability claim demand including reasonable attorney made third party arising site including site provide link another site upload content information site',
#  'question condition legal notice contact mail customercare regular mail attn customer international drive claire phone toll free customer customer outside hour week',
#  'site store continue implement technology improve product service provide notice policy subject change reserve right change update notice policy modify terminate site reason without notice without liability participating third party site user responsible regularly reviewing notice policy order remain informed practice obligation visit site current notice policy constitute entire agreement site supersedes prior understanding agreement written oral regard revised july',
#  'using accessing participating agree capitalized defined meaning forth condition located http reserve right change time post notice made change website least change posted indicate bottom date last revised revision become effective earlier foregoing period first time access change agree abide authorized access participate',
#  'provide type information information submit information regarding collected interact enter website collect browser type address information gathered website visitor addition store certain information browser using cooky cookie piece data stored user computer tied information user session cooky confirm user logged want information collected cooky simple procedure browser allows deny accept cookie feature however note cooky necessary provide certain feature customized delivery information available website registration process provide name email address hometown information requested registration process submit information content generate activity data engaging educational activity send message otherwise transmit information user store information provide offer personalized feature',
#  'contact information send notification regarding service offered partner think find valuable also send related announcement time time general operation generally email although reserve right send notice account even voluntary email notification information used primarily presented back edited access presented user case user able supplement including submitting comment aggregate anonymous data collected including activity data purpose data used shared third party manner',
#  'share personally identifiable information limited circumstance belief sharing reasonably necessary offer legally required permitted example provide personally identifiable information provider help bring hosting location facility sending email update connection operation provider access personally identifiable information limited time utilize provider processing personally identifiable information implement reasonable contractual protection limiting personally identifiable information provision service required disclose personally identifiable information pursuant lawful request subpoena court order compliance applicable additionally share account personally identifiable information believe necessary comply protect interest property prevent fraud illegal activity perpetrated using name prevent imminent harm include sharing personally identifiable information company lawyer agent government agency ownership substantially business individual business unit asset owned related change personally identifiable information transferred owner transfer information personally identifiable information would remain subject section',
#  'contain link website responsible practice website encourage user aware leave read statement website collect personally identifiable information applies solely information collected last revised april',
#  'browse usda website read page download information gather store certain information visit automatically technology gauge browsing habit surfing history improve information presented example search usda loan rural community website visit subsequent visit also provided information usda rural loan program information store identify personally automatically collect store following information visit internet domain address access website example access website school schoolname school address type browser operating system used access site date time access site page visit linked usda website another website address website information help make site useful learn number visitor site type technology visitor using visit website present relevant information based website browsing request track activity beyond browsing usda website cross browsing habit entity sell give away information entity',
#  'coppathis external link third party site outside state department agriculture usda website applies online collection personal information child usda complies coppa knowingly collect personal information child',
#  'visit website server generate piece information known cooky cooky collect personal information recognize computer future cooky small file server place user hard drive help website type cooky session cooky also known transient session cooky serve technical purpose like providing seamless navigation usda stored temporary memory available active browser session close browser cookie disappears persistent cooky also known permanent stored cooky used collect identifying information user user name surfing behavior user preference specific website cooky operate expire user deletes usda type cooky improve line service disable cooky adjusting setting browser',
#  'choose provide personal information mail secretary usda staff filling form submitting website information respond message also help locate information requested treat mail handle paper based correspondence sent usda required maintain many document federal record historical purpose collect personal information purpose respond share information give another government agency inquiry relates agency otherwise required moreover create individual profile information provide information provide shared private organization usda collect information commercial marketing',
#  'read statement website visit website link several federal agency case link private organization permission access another site link provide subject statement organization site',
#  'information presented usda website considered public information distributed copied appropriate byline photo image credit requested site security purpose ensure site remains available user usda employ monitoring technology identify unauthorized attempt upload change otherwise cause damage usda information system data scheduled regular destruction accordance computer fraud abuse external link third party site outside state department agriculture usda website national record administration nara general schedule unauthorized attempt upload information change information website strictly prohibited punishable national information infrastructure protection',
#  'impact assessment analysis information handled ensure handling conforms applicable legal regulatory requirement regarding determine risk effect collecting maintaining disseminating information identifiable form electronic information system examine evaluate protection alternative process handling information mitigate potential risk government requires federal agency conduct electronic information system collection general make assessment result publicly available learn usda impact assessment',
#  'provision government require agency human readable machine readable technology automatically alert user whether site practice match personal preference standard machine readable',
#  'usda third party service youtube communicate interact public encounter service separate website example usda pagethis external link third party site outside state department agriculture usda website application embedded within usda website service controlled operated third party government website application interacting usda third party service providing government third party access personal information used distinguish trace identity information collected third party subject policy third party provider third party service example persistent multi session cooky generally usda collect disseminate maintain personally identifiable information maintained third party site however aware usda read review rely upon information make publicly available usda service example comment made usda page authorized required note third party service supplement usda traditional communication outreach effort concern communicating usda channel traditional channel contact',
#  'purpose usda medium communication forum usda blog collaborative tool site share news information regarding activity policy program usda employee encourage discussion comment post insight important ensure american nationwide informed part usda work every comment question information presented forward concern usda officer payton payton ocio usda ocio usda',
#  'agreement mean current version agreement including incorporated licensed material mean intellectual property including limited logo trade name mark trademark trade dress membership mean anyone holding account compliance agreement mean membership information including limited legal name address telephone email product mean every product offer page mean page name website membership information shown service mean every offer website mean planet uniform resource identifier provide product service system mean software hardware whether owned leased otherwise contracted mean texas limited liability company mean person organization business entity seek service well agent assigns successor active group mean user post comment group information updated event mission created group inactive deleted back',
#  'direct question answered reading agreement support access website utilize service eighteen year otherwise competent enter binding contract service must read agree comply agreement understand accept agreement take effect moment access website amended modified unless agree otherwise writing amended modified time change shall take full effect soon posted website continued service shall irrefutable proof consent condition current version agreement entire agreement contain condition relationship service shall terminate condition provided herein agreement shall create agency employee employer franchis franchisee joint enterprise joint venture partnership relationship failure require performance provision agreement shall affect right require subsequent performance time provision determine sole discretion violated provision agreement applicable subsequent notice immediately lower suspend cancel account membership personal information collect pending applicable amount charge administrative cost connection violation provision agreement bring legal action enjoin violation collect damage caused violation agreement cooperate enforcement appropriate authority organization unless otherwise provided herein agree notice shall sent recent email address file deemed immediately delivered even allowed email address file longer valid notice shall sent support deemed immediately delivered back',
# ...
#  'managing career life long process retain information gather effort make repeat site efficient practical relevant change remove personal data described access review correct update change delete resume time account resume make desired change access correction update deletion personal information denied limited monster would violate another person right otherwise permitted applicable wish delete close account account information altogether click contact send email confirm personal information deleted save archival copy accessible third party internet archival copy retained long needed audit record purpose also keep information relate activity site respond information access request without undue delay receipt event within require additional time provide access information acknowledge receipt request within promptly supplement response within time period required applicable seeker public resume logged onto monster extended period make resume unsearchable separately regardless resume setting account significant period time expire scheduled deletion expired account deleted periodic basis current expiration period approximately month extend reduce period order adjust changing hiring pattern change period update notice always receive email delete resume manner',
#  'responsible keeping username password secret monster take appropriate measure secure personal information accidental loss unauthorized access alteration disclosure however internet open system cannot guarantee unauthorized third party able defeat measure personal information improper purpose find additional information conducting safe search security center aware resume monitored current employer place order online monster credit card information encrypted industry standard encryption make difficult credit card information intercepted stolen transmitted monster company process credit card transaction information company security practice click',
#  'monster intended knowingly collect information child',
#  'monster complies safe harbor framework swiss safe harbor framework forth department commerce regarding collection retention personal information european union member country switzerland monster certified adheres safe harbor principle notice choice onward transfer security data integrity access enforcement learn safe harbor program view monster certification visit http export safeharbor would like contact directly safe harbor program contact monster worldwide monster worldwide technology member truste seal program truste safe harbor seal program truste dispute resolution program consult truste website http truste information concerning truste program dispute resolution procedure truste program cover information collected monster truste logo appears cover information collected software downloaded monster live outside european economic area monster endeavor comply applicable international transfer personal information monster worldwide awarded truste seal signifying practice reviewed truste compliance truste program requirement',
#  'decide materially change substance required contact email address maintain also post change prominent notice site',
#  'data submitted monster worldwide hosted stored database server situated state owned maintained monster worldwide technology delaware corporation whose principal place business third avenue york york monster worldwide delaware corporation principal place business clock tower place maynard legal entity determining purpose mean processing information gathered monster site application data controller data stored monster database time question concern contact online office monster worldwide clock tower place suite maynard reasonable effort promptly answer question resolve problem feel properly addressed question contact truste notice california resident information california right click',
#  'cooky monster cooky help personalize maximize online experience time online including storing user preference improving search result selection tracking user trend cookie text file stored computer cooky store information help make site work code contain virus read cooky except cooky improve experience site following type cooky security cooky allow secure access account preference cooky used store preference like language choice display search result analytics track traffic pattern identify popular content potential problem feature track search view apply show like also cooky split user test group test feature advertising identifiable information show advertising cooky remain computer left site security cooky remain last visit poll response cooky remain monster cooky relating advertisement site notice remain year also allow company display advertisement using site application browser must request advertisement company server company view edit cooky requested page site monster control responsible practice third party advertiser data stored cooky anonymous information linked personally identifiable information without permission cooky placed third party server remain computer left site year unless choose delete advertising monster several third party help provide analytics service serve advertisement including doubleclick atlas solution omniture click list many company monster work connection serving personalized third party cooky setting browser decline cooky otherwise wish allow session visitation information site aggregated analyzed omniture used omniture tailor dynamic content specific interest utilize following mechanism omniture optout monster respond browser track signal targeted advertising network monster work clicking also cooky connection career network cookie used display relevant monster visit website cookie http monster cookie technology aspx note delete browser cooky cookie also deleted additionally change computer browser need monster also flash cooky also known local shared object preserve video player setting user authentication purpose adjust setting flash cooky beacon javascript monster beacon sometimes called pixel clear gifs action javascript collect information user visit site application measure improve effectiveness advertisement posting deliver branded service help compile aggregated statistic site usage beacon built page cannot refused however rendered ineffective opting cooky javascript deactivated browser setting disable javascript able function website',
#  'social medium widget site includes social medium feature like button widget share button feature collect address page site visiting cookie enable feature function properly social medium feature either hosted third party hosted directly site interaction feature governed company providing referral choose share site content friend friend name email address automatically send friend time email inviting visit site monster worldwide temporarily store information sole purpose sending time email',
#  'collect store following information running information provide register account collect personal information name phone number credit card billing information email address home business postal address also import contact giving access third party service example email account social networking information give access account social network connection service invite others join using referral page send time email referral also provide contact email address sharing folder file also receive personal information example email address user example tried share something tried refer file collect store file upload download access file file previously uploaded another user associate portion previous file account rather storing duplicate data automatically record information device software activity using service include device internet protocol address browser type page visited came website information search website locale preference identification number associated device mobile carrier date time stamp associated transaction system configuration information metadata concerning file interaction cooky also cooky collect information improve service cookie small data file transfer device persistent cooky save registration login password future logins session cooky enable certain feature better understand interact monitor aggregate usage traffic routing instruct browser changing option stop accepting cooky prompt accepting cookie website visit accept cooky however able aspect',
#  'personal information course using collect personal information used contact identify personal information personal information used provide improve administer better understand need interest personalize improve experience provide offer software update product announcement longer wish receive communication follow unsubscribe instruction provided communication update account setting information location information device allow application access real time location based information example mobile apps collect information mobile device time download mobile apps date went effect future consent improve service photo video place contain recorded location information information optimize experience wish share file embedded location information upload want store location data photo video consult documentation camera turn feature also information collect device example address sometimes used approximate device location analytics also collect information using third party service using logging cooky address sometimes correlated personal information information purpose monitor analyze technical administration increase functionality user friendliness verify user authorization needed process request date went effect analytics learn analytics click learn click',
#  'display personal information page elsewhere according preference account information choose provide reflect much want others know consider carefully information disclose page desired level anonymity review revise information time sell personal information third party also share disclose information consent example third party application access account certain feature also ability make information public public information broadly quickly disseminated provider business partner others certain trusted third party company individual help provide analyze improve including limited data storage maintenance service database management analytics payment processing improvement feature third party access information purpose performing task behalf obligation similar date went effect storage store information example file find information data security site read securely store data third party application share information third party application consent example choose access service application responsible party information make sure trust application acceptable compliance enforcement request protection right disclose party outside file stored information collect good faith belief disclosure reasonably necessary comply regulation compulsory legal request protect safety person death serious bodily injury prevent fraud abuse user protect property right provide file enforcement agency forth remove encryption file providing enforcement however able decrypt file encrypted prior storing business transfer involved merger acquisition sale portion asset information transferred part transaction notify example email prominent notice website change control personal information file either become subject different also notify choice regarding information private personal information disclose private aggregated otherwise personal information usage statistic',
#  'registered user review update correct delete personal information provided registration account changing account setting personally identifiable information change longer desire update delete making change account setting case retain copy information required question personal information contact respond inquiry within',
#  'retain information long account active needed provide service wish cancel account request longer information provide service delete account retain information necessary comply legal obligation resolve dispute enforce agreement consistent requirement delete information quickly upon request note however might latency deleting information server backed version might exist deletion addition delete server file common user',
#  'business account administrator able access information business account disclose restrict access information provided made available using business account control business account accessed deleted refer organization policy question administrator right',
#  'offer publicly accessible community service blog forum wikis aware information provide area read collected used others access post remain even cancel account question personal information contact site includes link site whose practice differ submit personal information site information governed statement encourage carefully read statement site visit',
#  'security information important enter sensitive information credit card number order form encrypt transmission information using secure socket layer technology follow generally accepted standard protect information submitted transmission receive method electronic transmission storage secure however therefore cannot guarantee absolute security question security website view security overview page contact security',
#  'service directed person knowingly collect personally identifiable information child parent guardian becomes aware child provided personal information without consent contact become aware child provided personal information take step delete information file',
#  'received truste seal signifying statement practice reviewed truste compliance truste program requirement including transparency accountability choice regarding collection personal information truste program cover information collected downloadable software complies safe harbor framework swiss safe harbor framework forth department commerce regarding collection retention personal data european union member country switzerland certified adheres safe harbor principle notice choice onward transfer security data integrity access enforcement learn safe harbor program view certification visit http export safeharbor question regarding statement first contact receive acknowledgement inquiry inquiry satisfactorily addressed contact truste http truste consumer mail truste safe harbor compliance dept click mailing address truste dispute resolution process available english',
#  'question contact berry street floor francisco',
#  'change time time make change believe materially reduces right provide notice example email provide notice change circumstance well continuing change become effective agree bound revised',
#  ...]

# %%
dump(pp_data_words, open("/Users/dbm/Documents/Insight S19/data/acl_privacy_policy_words.pkl", "wb"))

# %%
##### References
# - Inproceedings (ramanath:2014,
#     author = {Rohan Ramanath and Fei Liu and Norman Sadeh and Noah Smith},
#     booktitle = {Proceedings of ACL},
#     month = {June},
#     publisher = {Association for Computational Linguistics},
#     title = {Unsupervised Alignment of Privacy Policies using Hidden Markov Models},
#     year = {2014})
